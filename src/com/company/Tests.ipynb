# %%
"""
These tests are an important sanity check

If any modification ruins the test functionality then we can be sure 
that the modification is detrimental
"""

# Add Backend to path
import sys
sys.path.append('C:/Users/eeveetza/Documents/GitHub/AlgoBrain/src/com/company/Backend')

from Environment import World
from Experiment import Experiment

"""
Mapping integers - instructions:
    
0  <==> NopA
1  <==> NopB
2  <==> NopC
3  <==> IfNEq
4  <==> IfLess
5  <==> Swap
6  <==> Pop
7  <==> Push
8  <==> SwapStack
9  <==> RightShift
10 <==> LeftShift
11 <==> Inc
12 <==> Dec
13 <==> Add
14 <==> Sub
15 <==> Nand
16 <==> HAlloc
17 <==> HDivide
18 <==> IO
19 <==> HCopy
20 <==> HSearch
21 <==> MovHead
22 <==> JmpHead
23 <==> GetHead£
24 <==> SetFlow
25 <==> IfLabel

"""

# clears all registers (under the assumption that the active stack is empty)
clear = [6, 0, 6, 1, 6, 2]

# Custom made test instructions
program_not = [6, 1, 18, 2, 14,0, 12, 0, 18, 0] + clear
program_nand = [18,1,18,2,15,0,18,0] + clear
program_and = [18,1,18,2,15,2,6,1,14,0,12,0,18,0] + clear
program_or = [6, 1, 18, 2, 14, 0, 12, 0, 6, 1, 18, 2, 14, 2, 12, 2, 7, 0, 6, 1, 15, 0, 18, 0] + clear
program_or_n = [6, 1, 18, 2, 14, 2, 12, 2, 18, 1, 15, 0, 18, 0] + clear
program_and_n = [6, 1, 18, 2, 14, 2, 12, 2, 18, 1, 15, 2, 6, 1, 14, 0, 12, 0, 18, 0] + clear
program_nor = [18, 2, 14, 0, 12, 0, 6, 1, 18, 2, 14, 2, 12, 2, 7, 0, 6, 1, 15, 2, 6, 1, 14, 0, 12, 0, 18, 0] + clear
program_xor = [18, 0, 18, 2, 7, 0, 7, 2, 8, 14, 2, 12, 2, 7, 0, 6, 1, 6, 0, 15,\
           2, 6, 1, 7, 2, 8, 6, 0, 6, 2, 14, 2, 12, 2, 7, 0, 6, 1, 6, 0, 15, 2, 8, 6, 1, 15, 0, 18, 0] + clear
program_equ = [18, 1, 18, 2, 7, 1, 7, 2, 8, 15, 2, 6, 1, 7, 2, 8, 6, 0, 6, 2, 14, 2, 12, 2, 7,\
               2, 7, 0, 6, 2, 14, 2, 12, 2, 6, 1, 15, 2, 8, 6, 1, 15, 0, 18, 0]

# %%
#%%
"""
Parser to create instructions by reading input stream

All instructions to be written lowercase without dashes
"""

result = []
instr = []
while True:
    data = input("Instructions: ")
    if data == "end":
            print("result = " + str(result))
            break
    else:
        number_of_empty_responses = 0
        
        # Boring case checking
        if data == "nopa" or data == "a":
            result.append(0)
            instr.append("nopa")
        elif data == "nopb" or data == "b":
            result.append(1)
            instr.append("nopb")
        elif data == "nopc" or data == "c":
            result.append(2)
            instr.append("nopc")
        elif data == "ifneq":
            result.append(3)
        elif data == "ifless":
            result.append(4)
        elif data == "swap":
            result.append(5)
        elif data == "pop":
            result.append(6)
        elif data == "push":
            result.append(7)
        elif data == "swapstack":
            result.append(8)
        elif data == "rshift":
            result.append(9)
        elif data == "lshift":
            result.append(10)
        elif data == "inc":
            result.append(11)
        elif data == "dec":
            result.append(12)
        elif data == "add":
            result.append(13)
        elif data == "sub":
            result.append(14)
        elif data == "nand":
            result.append(15)
        elif data == "halloc":
            result.append(16)
        elif data == "hdivide":
            result.append(17)
        elif data == "io":
            result.append(18)
        elif data == "hcopy":
            result.append(19)
        elif data == "hsearch":
            result.append(20)
        elif data == "movhead":
            result.append(21)
        elif data == "jmphead":
            result.append(22)
        elif data == "gethead":
            result.append(23)
        elif data == "setflow":
            result.append(24)
        elif data == "iflabel":
            result.append(25)
        elif data == "consume":
            result.append(26)
        elif data == "back":
            result.pop(-1)
        elif data == "clear":
            result = []
        print(result)

# %%
#%%
"""
Test 1:
    
    An organism that computes NOT
    
    NOT(A) == -A - 1
    
    POP-B
    IO-C
    SUB-A
    DEC-A
    IO-A
    
"""
instructions = program_not

world = World(1, replacement_strategy = "neighborhood", cm_prob = 0, ins_prob = 0, del_prob = 0,notify_ = True)

world.place_custom(program_not)

world.schedule(13)

# %%
#%%
"""
Test 2:
    
    An organim that computes NAND
    
    IO-B
    IO-C
    NAND-A
    IO-A
    
"""
world = World(1, replacement_strategy = "neighborhood", cm_prob = 0, ins_prob = 0, del_prob = 0, notify_ = True)

world.place_custom(program_nand)

world.schedule(10)

# %%
"""
Test 3:
    
    An organism that computes AND
    
    Serial connection NAND => NOT
    
    AND(A,B) = NOT(NAND(A,B))
    
    IO-B
    IO-C
    NAND-C
    POP-B
    SUB-A
    INC-A
    IO-A
    
"""
world = World(1, replacement_strategy = "neighborhood", cm_prob = 0, ins_prob = 0, del_prob = 0, notify_ = True)

world.place_custom(program_and)

world.schedule(9)

# %%
"""
Test 4:
    
    An organism that computes OR
    
    OR(A,B) == NOT(NOT(A) AND NOT(B))
    
    NOT(A) AND NOT(B) = NOT(NAND(NOT(A),NOT(B)))
    
    All together:
    
        OR(A,B) = NAND(NOT(A),NOT(B))
        
    
    #1: 
        Save NOT(A) in regA
        
        POP-B
        IO-C
        SUB-A
        DEC-A
        
    #2:
        Save NOT(B) in regC
        
        POP-B
        IO-C
        SUB-C
        DEC-C
        
    #3:
        Move regA to regB
        
        PUSH-A
        POP-B
    
    #4:
        NAND to regA, IO-A
        
        NAND-A
        IO-A
"""
world = World(1, replacement_strategy = "neighborhood", cm_prob = 0, ins_prob = 0, del_prob = 0, notify_ = True)

world.place_custom(program_or)

world.schedule(15)

# %%
"""
Test 5:
    
    An organism that computes OR_N
    
    Take A OR NOT(B)
    
    A OR NOT(B) = NOT(A) NAND B
    
    # Save NOT(A) to C
    # Input B
    # NAND to A
    # IO-A
    
    
"""
world = World(1, replacement_strategy = "neighborhood", cm_prob = 0, ins_prob = 0, del_prob = 0, notify_ = True)

world.place_custom(program_or_n)

world.schedule(10)

# %%
"""
Test 6:
    
    An organism that computes AND_N
    
    Take A AND NOT(B)
    
    a and not(b) = not(a nand not(b))
    
    # Save NOT(B) to regC
    # Load A to regB
    # NAND-C
    # POP-B
    # SUB-A
    # DEC-A
    # IO-A
    
"""
world = World(1, replacement_strategy = "neighborhood", cm_prob = 0, ins_prob = 0, del_prob = 0, notify_ = True)

world.place_custom(program_and_n)

world.schedule(12)

# %%
"""
Test 7:
    
    An organism that computes NOR
    
    NOT(A OR B)
    
    A OR B = NAND(NOT(A),NOT(B))
    
    How to do it:
        
    #1: 
        Save NOT(A) in regA
        
        IO-C
        SUB-A
        DEC-A
        
    #2:
        Save NOT(B) in regC
        
        POP-B
        IO-C
        SUB-C
        DEC-C
        
    #3:
        Move regA to regB
        
        PUSH-A
        POP-B
    
    #4:
        NAND to regC
        
        NAND-C
        
    #5: Clear B
        POP-B
        
    #6: Sub to A, Dec A, IO A
    
"""
world = World(1, replacement_strategy = "neighborhood", cm_prob = 0, ins_prob = 0, del_prob = 0, notify_ = True)

world.place_custom(program_nor)

world.schedule(20)

# %%
"""
Test 8:
    
    An organism that computes XOR
    
    (A and ~B) or (~A and B)
    
    NOT(NAND(A,NOT(B))) OR NOT(NAND(NOT(A),B))
    
    This ends up being equivalent to
    
    nand(nand(a,not(b)),nand(not(a),b))
    
    #1:
        input one to a
        input other to c
        push both to stack for later use. push 2nd input first and then the first one
        switch stack for popping
        calculate not(other) as:
            sub-c
            dec-c
        move first one from a to b by doing:
            push-a
            pop-b
            pop-a
        
        now we have:
            reg_a = 0
            reg_b = Input0
            reg_c = not(Input1)
            stack = (b,a)
        we just nand this to c
        pop-b
        push-c
        
        repeat first part
        
        swap stack
        pop a
        pop c
        
        Detailed Guide:
            
            # Inputing and saving to stack:
                IO-A
                IO-C
                PUSH-A
                PUSH-C
                
            Stack0 now is [i1,i0]
            
            Registers are:
                A = i0
                B = 0
                C = i1
                
            swapstack
            
            # Calculating not(i1):
                sub-c
                dec-c
                
            # Move one from A to B:
                push-a
                pop-b
                pop-a
                
                
            Registers are:
                
                regA = 0
                regB = A
                regC = NOT(B)
                
            # Nand them to C:
                
                nand-c
                
            # pop b to clear it:
                pop-b
            
            push-c
            
            now the second stack has nand(a,not(b)) in it.
            Switching to first stack with [b,a] in it
            
            swapstack
            pop-a
            pop-c
            
            # do not of register C which contains A
            
            sub-c
            dec-c
            
            # move B from A to regB
            
            push-a
            pop-b
            pop-a
            
            # Registers now:
                
                regA = 0
                regB = B
                regC = not(A)
            
            # nand them to c
            nand-c
            
            # swap to other stack
            
            swapstack
            
            # retrieve first result to regb
            
            pop-b
            
            # nand
            nand-a
            
            io-a
        
"""
world = World(1, replacement_strategy = "neighborhood", cm_prob = 0, ins_prob = 0, del_prob = 0, notify_ = True)

world.place_custom(program_xor)

world.schedule(30)

# %%
"""
Test EQU:
    
    An organism that computes EQU
    
    EQU(A,B) = (A and B) or (~A and ~B)
    
    not(nand(a,b)) or not(nand(not(a),not(b)))
    
    nand(nand(a,b),nand(not(a),not(b)))
    
    #0: Input a,b; store in active stack
    #1: Switch stack
    #2: Compute nand(a,b)
    #3: Clear register b
    #4: Store nand(a,b) to stack
    #5: Switch stack
    #6: Put a to reg_a, b to reg_c
    #7 : Calculate not(b) in reg_c, store to stack
    #8: Move a to reg_c by doing push-a pop-c
    #9: Calculate not(a) in reg_c
    #10: pop not(b) to reg_b
    #11: nand them to c
    #12: swap stack
    #13: pop to b
    #14: nand to a
    #15: io-a
        
"""
world = World(1, replacement_strategy = "neighborhood", cm_prob = 0, ins_prob = 0, del_prob = 0, notify_ = True)

world.place_custom(program_equ)

world.schedule(30)

# %%
"""
Test 9:
    
    Move Up
    
"""

program = [27,0,0,1,2]

world = World(2, replacement_strategy = "neighborhood", cm_prob = 0, ins_prob = 0, del_prob = 0)

world.place_custom(program,(1,0))

print("Before Moving Up")
print(world.pool.get())


world.schedule(1)

print("\nAfter Moving Up")
print(world.pool.get())

# %%
"""
Test 10:
    
    Move Down
    
"""

program = [28,0,0,1,2]

world = World(2, replacement_strategy = "neighborhood", cm_prob = 0, ins_prob = 0, del_prob = 0)

world.place_custom(program,(0,0))

print("Before Moving Down")
print(world.pool.get())


world.schedule(1)

print("\nAfter Moving Down")
print(world.pool.get())

# %%
"""
Test 11:
    
    Move Left
    
"""

program = [29,0,0,1,2]

world = World(2, replacement_strategy = "neighborhood", cm_prob = 0, ins_prob = 0, del_prob = 0)

world.place_custom(program,(0,1))

print("Before Moving Left")
print(world.pool.get())


world.schedule(1)

print("\nAfter Moving Left")
print(world.pool.get())

# %%
"""
Test 12:
    
    Move Right
    
"""

program = [30,0,0,1,2]

world = World(2, replacement_strategy = "neighborhood", cm_prob = 0, ins_prob = 0, del_prob = 0)

world.place_custom(program,(0,0))

print("Before Moving Right")
print(world.pool.get())


world.schedule(1)

print("\nAfter Moving Right")
print(world.pool.get())

# %%
"""
Test 13:
    
    Consume
"""

print("A demonstration of the Consume instruction:\n")

program_predator = [26] + (len(program_xor))*[0]
program_prey = program_xor

world = World(2, replacement_strategy = "neighborhood", cm_prob = 0, ins_prob = 0, del_prob = 0, notify_ = True)

world.place_custom(program_predator, position = (0,0))
world.place_custom(program_prey, position = (0,1))

print(world)

world.schedule(1)

print("An emulator has now been consumed. The predator can now output XOR, a powerful function\n")
print(world)

print("Running for a further 30 cycles produces:")

world.schedule(30)

# %% [markdown]
# ### Here we can easily test any organism we've found:

# %%
experiment = Experiment(start_organism="nor", target_function="xor", ins_prob = 0.4,N=30)
experiment.run()
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-14-98241f2a5c16> in <module>
#       1 experiment = Experiment(start_organism="nor", target_function="xor", ins_prob = 0.4,N=30)
# ----> 2 experiment.run()
#
# ~\Documents\GitHub\AlgoBrain\src\com\company\Experiment.py in run(self)
#     271
#     272         while self.first_specimen == None:
# --> 273             self.world.schedule(1)
#
# C:/Users/eeveetza/Documents/GitHub/AlgoBrain/src/com/company/Backend\Environment.py in schedule(self, n_loops, n_notify)
#     211
#     212                                 current_emulator = self.pool.get()[i][j]
# --> 213                                 current_emulator.execute_instruction()
#     214                                 self.ages[i][j] = current_emulator.age
#     215
#
# C:/Users/eeveetza/Documents/GitHub/AlgoBrain/src/com/company/Backend\DigitalOrganism.py in execute_instruction(self)
#     118         ip = self.instr_pointer.get()
#     119
# --> 120         self.instruction_memory.get(ip).execute()
#     121
#     122         self.age += 1
#
# C:/Users/eeveetza/Documents/GitHub/AlgoBrain/src/com/company/Backend\Instructions.py in execute(self)
#     485
#     486         # Notify the world about IO
# --> 487         self.emulator.mediator.notify(sender = self.emulator, event = "IO_operation", result = to_output)
#     488
#     489         # get: return value from input buffer into ?BX?
#
# C:/Users/eeveetza/Documents/GitHub/AlgoBrain/src/com/company/Backend\Environment.py in notify(self, sender, event, result)
#     223
#     224         if event == "IO_operation":
# --> 225             self.react_on_IO(sender, result)
#     226
#     227         if event == "len_change":
#
# C:/Users/eeveetza/Documents/GitHub/AlgoBrain/src/com/company/Backend\Environment.py in react_on_IO(self, sender, result)
#     595         # Find the position in the pool where the sender is at:
#     596         idx0 = np.where(self.pool.get() == sender)[0][0]
# --> 597         idx1 = np.where(self.pool.get() == sender)[1][0]
#     598
#     599         # If the most recent input is none, do nothing
#
# <__array_function__ internals> in where(*args, **kwargs)
#
# KeyboardInterrupt:

# %%
em = experiment.world.pool.get((0,0))

# %%
print(em.original_memory)
# Out:
# [10, 20, 2, 0, 21, 2, 13, 9, 13, 7, 13, 3, 23, 17, 7, 3, 7, 15, 20, 17, 22, 9, 18, 2, 12, 14, 2, 1, 18, 15, 11, 16, 0, 13, 7, 9, 2, 18, 17, 20, 3, 19, 19, 25, 2, 0, 17, 21, 0, 1]

# %%
em.child_rate
# Out:
# 1

# %%
em.mutation_prob
# Out:
# 0.05

# %%
len(em.original_memory)
# Out:
# 50

# %%
experiment.world.schedule(50)

# %%
l = 0
selected = None
for i in range(30):
    for j in range(30):
        if len(experiment.world.get((i,j)).original_memory) > 0:
            print(len(experiment.world.get((i,j)).original_memory))
            if len(experiment.world.get((i,j)).original_memory) == 10 and selected == None:
                selected = experiment.world.get((i,j)).original_memory
                em = experiment.world.get((i,j))
# Out:
# 51
# 51
# 51
# 51
# 52
# 51
# 12
# 50
# 51
# 50
# 50
# 53
# 52
# 54
# 51
# 49
# 50
# 50
# 50
# 50
# 50
# 49
# 51
# 10
# 52
# 52
# 51
# 10
# 51
# 50
# 43
# 28
# 52
# 51
# 51
# 50
# 51
# 50
# 51
# 51
# 10
# 51
# 53
# 54
# 10
# 49
# 50
# 50
# 50
# 10
# 50
# 49
# 48
# 10
# 52
# 51
# 10
# 50
# 50
# 50
# 50
# 50
# 50
# 50
# 50
# 50
# 50
# 50
# 51
# 51
# 10
# 10
# 52
# 51
# 12
# 51
# 51
# 50
# 10
# 10
# 51
# 51
# 10
# 50
# 50
# 10
# 43
# 51
# 54
# 50
# 10
# 10
# 51
# 52
# 50
# 10
# 52
# 50
# 51
# 41
# 10
# 51
# 10
# 12
# 39
# 51
# 51
# 49
# 51
# 52
# 10
# 43
# 51
# 51
# 10
# 53
# 51
# 10
# 50
# 53
# 52
# 51
# 51
# 51
# 51
# 51
# 50
# 51
# 10
# 50
# 10
# 42
# 42
# 51
# 51
# 50
# 10
# 51
# 51
# 10
# 52
# 41
# 51
# 10
# 10
# 10
# 41
# 52
# 10
# 10
# 10
# 51
# 49
# 50
# 51
# 10
# 51
# 51
# 50
# 50
# 10
# 51
# 10
# 50
# 51
# 52
# 10
# 39
# 10
# 51
# 51
# 12
# 10
# 51
# 52
# 53
# 51
# 51
# 51
# 50
# 51
# 49
# 49
# 50
# 51
# 50
# 10
# 51

# %%
selected
# Out:
# [10, 20, 2, 0, 21, 2, 13, 22, 13, 7]

# %%
em.child_rate
# Out:
# 1

# %%
import numpy as np
np.max(experiment.world.ages)
# Out:
# 284

# %%
program = experiment.first_specimen

world = World(3, replacement_strategy = "neighborhood", cm_prob = 0, ins_prob = 0, del_prob = 0, notify_ = True)

world.place_custom([0, 5, 20, 0, 21, 2, 16, 14, 10, 20, 14, 19, 25, 0, 17, 5, 21, 10, 1])

world.schedule(150)

# %%
print(world.pool.get())
# Out:
# [[0 0 0]
#  [<DigitalOrganism.CPUEmulator object at 0x0000022E232D8A90> 0 0]
#  [0 <DigitalOrganism.CPUEmulator object at 0x0000022E22B08D30> 0]]

# %%
experiment.test(n=10000)
# Out:
# EMULATOR AT POSITION (0, 0) COMPUTED NOR
# INPUT: [2844876770 3388568487]
# OUTPUT:  369524760
# Notifying experiment of function_IO
# Reacting on IO
# 2844876770 3388568487 369524760
# Test passed
#
# EMULATOR AT POSITION (0, 0) COMPUTED NOR
# INPUT: [3119115574  127850431]
# OUTPUT:  1073741888
# Notifying experiment of function_IO
# Reacting on IO
# 3119115574 127850431 1073741888
# Test passed
#
# EMULATOR AT POSITION (0, 0) COMPUTED NOR
# INPUT: [4144310577 2442287200]
# OUTPUT:  141067918
# Notifying experiment of function_IO
# Reacting on IO
# 4144310577 2442287200 141067918
# Test passed
#
# EMULATOR AT POSITION (0, 0) COMPUTED NOR
# INPUT: [ 149647922 1701172496]
# OUTPUT:  2450524365
# Notifying experiment of function_IO
# Reacting on IO
# 149647922 1701172496 2450524365
# Test passed
#
# EMULATOR AT POSITION (0, 0) COMPUTED NOR
# INPUT: [ 770383316 3865763848]
# OUTPUT:  269746723
# Notifying experiment of function_IO
# Reacting on IO
# 770383316 3865763848 269746723
# Test passed
#
# EMULATOR AT POSITION (0, 0) COMPUTED NOR
# INPUT: [1939988513 3433030020]
# OUTPUT:  4202074
# Notifying experiment of function_IO
# Reacting on IO
# 1939988513 3433030020 4202074
# Test passed
#
# EMULATOR AT POSITION (0, 0) COMPUTED NOR
# INPUT: [3613505925 4191634522]
# OUTPUT:  524832
# Notifying experiment of function_IO
# Reacting on IO
# 3613505925 4191634522 524832
# Test passed
#
# EMULATOR AT POSITION (0, 0) COMPUTED NOR
# INPUT: [3291505133 3235597405]
# OUTPUT:  990155266
# Notifying experiment of function_IO
# Reacting on IO
# 3291505133 3235597405 990155266
# Test passed
#
# EMULATOR AT POSITION (0, 0) COMPUTED NOR
# INPUT: [1072391044 1822722386]
# OUTPUT:  2148537385
# Notifying experiment of function_IO
# Reacting on IO
# 1072391044 1822722386 2148537385
# Test passed
#
# EMULATOR AT POSITION (0, 0) COMPUTED NOR
# INPUT: [1157466146 2361167226]
# OUTPUT:  855798405
# Notifying experiment of function_IO
# Reacting on IO
# 1157466146 2361167226 855798405
# Test passed
#
# EMULATOR AT POSITION (0, 0) COMPUTED NOR
# INPUT: [ 133676848 3291128666]
# OUTPUT:  939540613
# Notifying experiment of function_IO
# Reacting on IO
# 133676848 3291128666 939540613
# Test passed
#
# EMULATOR AT POSITION (0, 0) COMPUTED NOR
# INPUT: [ 393973585 3607614574]
# OUTPUT:  679485568
# Notifying experiment of function_IO
# Reacting on IO
# 393973585 3607614574 679485568
# Test passed
#
# EMULATOR AT POSITION (0, 0) COMPUTED NOR
# INPUT: [3764322943 3111566952]
# OUTPUT:  109068672
# Notifying experiment of function_IO
# Reacting on IO
# 3764322943 3111566952 109068672
# Test passed
#
# EMULATOR AT POSITION (0, 0) COMPUTED NOR
# INPUT: [1016656614 1626107741]
# OUTPUT:  2198011904
# Notifying experiment of function_IO
# Reacting on IO
# 1016656614 1626107741 2198011904
# Test passed
#
# EMULATOR AT POSITION (0, 0) COMPUTED NOR
# INPUT: [3537790442 3542927195]
# OUTPUT:  738269188
# Notifying experiment of function_IO
# Reacting on IO
# 3537790442 3542927195 738269188
# Test passed
#
# EMULATOR AT POSITION (0, 0) COMPUTED NOR
# INPUT: [ 718307098 2687816527]
# OUTPUT:  1426784416
# Notifying experiment of function_IO
# Reacting on IO
# 718307098 2687816527 1426784416
# Test passed
#
# EMULATOR AT POSITION (0, 0) COMPUTED NOR
# INPUT: [3909949398 3101875329]
# OUTPUT:  101720104
# Notifying experiment of function_IO
# Reacting on IO
# 3909949398 3101875329 101720104
# Test passed
#
# EMULATOR AT POSITION (0, 0) COMPUTED NOR
# INPUT: [ 354850611 1593750312]
# OUTPUT:  2684438724
# Notifying experiment of function_IO
# Reacting on IO
# 354850611 1593750312 2684438724
# Test passed
#
# EMULATOR AT POSITION (0, 0) COMPUTED NOR
# INPUT: [1725824102 3357895909]
# OUTPUT:  285344536
# Notifying experiment of function_IO
# Reacting on IO
# 1725824102 3357895909 285344536
# Test passed
#
# EMULATOR AT POSITION (0, 0) COMPUTED NOR
# INPUT: [2989428536 2073458476]
# OUTPUT:  71336131
# Notifying experiment of function_IO
# Reacting on IO
# 2989428536 2073458476 71336131
# Test passed
#
# EMULATOR AT POSITION (0, 0) COMPUTED NOR
# INPUT: [2061511933 1239569273]
# OUTPUT:  2216525826
# Notifying experiment of function_IO
# Reacting on IO
# 2061511933 1239569273 2216525826
# Test passed
#
# EMULATOR AT POSITION (0, 0) COMPUTED NOR
# INPUT: [1247157555 3040870180]
# OUTPUT:  8388808
# Notifying experiment of function_IO
# Reacting on IO
# 1247157555 3040870180 8388808
# Test passed
#
# EMULATOR AT POSITION (0, 0) COMPUTED NOR
# INPUT: [3942831973 2392761886]
# OUTPUT:  274794624
# Notifying experiment of function_IO
# Reacting on IO
# 3942831973 2392761886 274794624
# Test passed
#
# EMULATOR AT POSITION (0, 0) COMPUTED NOR
# INPUT: [3531091730 3492650150]
# OUTPUT:  763510857
# Notifying experiment of function_IO
# Reacting on IO
# 3531091730 3492650150 763510857
# Test passed
#
# EMULATOR AT POSITION (0, 0) COMPUTED NOR
# INPUT: [2507967546 2067878465]
# OUTPUT:  8528260
# Notifying experiment of function_IO
# Reacting on IO
# 2507967546 2067878465 8528260
# Test passed
#
# EMULATOR AT POSITION (0, 0) COMPUTED NOR
# INPUT: [ 818593957 4215856384]
# OUTPUT:  70591066
# Notifying experiment of function_IO
# Reacting on IO
# 818593957 4215856384 70591066
# Test passed
#
# EMULATOR AT POSITION (0, 0) COMPUTED NOR
# INPUT: [2723244521 1063820180]
# OUTPUT:  1082524674
# Notifying experiment of function_IO
# Reacting on IO
# 2723244521 1063820180 1082524674
# Test passed
#
# EMULATOR AT POSITION (0, 0) COMPUTED NOR
# INPUT: [3358027844 1102504087]
# OUTPUT:  910692136
# Notifying experiment of function_IO
# Reacting on IO
# 3358027844 1102504087 910692136
# Test passed
#
# EMULATOR AT POSITION (0, 0) COMPUTED NOR
# INPUT: [2921361675 3850117837]
# OUTPUT:  277056560
# Notifying experiment of function_IO
# Reacting on IO
# 2921361675 3850117837 277056560
# Test passed
#
# EMULATOR AT POSITION (0, 0) COMPUTED NOR
# INPUT: [ 255629108 2803722642]
# OUTPUT:  1354891337
# Notifying experiment of function_IO
# Reacting on IO
# 255629108 2803722642 1354891337
# Test passed
#
# EMULATOR AT POSITION (0, 0) COMPUTED NOR
# INPUT: [2126072570 3398856422]
# OUTPUT:  21008641
# Notifying experiment of function_IO
# Reacting on IO
# 2126072570 3398856422 21008641
# Test passed
#
# EMULATOR AT POSITION (0, 0) COMPUTED NOR
# INPUT: [1190148990 1613026690]
# OUTPUT:  2567634945
# Notifying experiment of function_IO
# Reacting on IO
# 1190148990 1613026690 2567634945
# Test passed
#
# EMULATOR AT POSITION (0, 0) COMPUTED NOR
# INPUT: [2769400086  455207694]
# OUTPUT:  1087243489
# Notifying experiment of function_IO
# Reacting on IO
# 2769400086 455207694 1087243489
# Test passed
#
# EMULATOR AT POSITION (0, 0) COMPUTED NOR
# INPUT: [3883340212 3369578954]
# OUTPUT:  268979713
# Notifying experiment of function_IO
# Reacting on IO
# 3883340212 3369578954 268979713
# Test passed
#
# EMULATOR AT POSITION (0, 0) COMPUTED NOR
# INPUT: [ 22574220 775811167]
# OUTPUT:  3498183456
# Notifying experiment of function_IO
# Reacting on IO
# 22574220 775811167 3498183456
# Test passed
#
# EMULATOR AT POSITION (0, 0) COMPUTED NOR
# INPUT: [1514118923 1233390618]
# OUTPUT:  2755682532
# Notifying experiment of function_IO
# Reacting on IO
# 1514118923 1233390618 2755682532
# Test passed

# %% [markdown]
# # Debugging:

# %% [markdown]
# ### 1: Find out what those organisms of length 10 are
