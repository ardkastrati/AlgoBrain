# %% [markdown]
# # Running Experiments for Default to NOR evolution with different system parameters.

# %%
import numpy as np
import matplotlib.pyplot as plt

# Add Backend to path
import sys
sys.path.append('C:/Users/eeveetza/Documents/GitHub/AlgoBrain/src/com/company/Backend')
#sys.path.append('C:/Users/alexa/OneDrive/Documents/GitHub/AlgoBrain/src/com/company/Backend')
#sys.path.append('C:/Users/Tbuob/OneDrive/Dokumente/GitHub/AlgoBrain/src/com/company/Backend')

from Environment import World
from Experiment import Experiment

# %% [markdown]
# Define the Experiment

# %%
# %%time

# Define the size of the pool here:
N = 30

# Define the start, targ£et and parameters of the experiment

# stat_cycles determines how often you're informed of the statistics of the population

experiment = Experiment(start_organism="default", target_function="nor", ins_prob = 0.05,\
                        del_prob = 0.05, cm_prob = 0.005,N=N, update_cycles = 6, instruction_set = "custom")
# Out:
# Wall time: 252 ms

# %% [markdown]
# Run the Experiment

# %%
# %%time

# Runs the experiment and looks for the target function
experiment.run()

# Captures the emulator which computes the functions realiably for further analysis
em = None

counter = 0

for i in range(N):
    for j in range(N):
        if experiment.world.pool.get((i,j)).original_memory == experiment.first_specimen:
            counter += 1
            em = experiment.world.pool.get((i,j))
# Out:
# UPDATE: 6
# Min Length: (50, (0, 0))
# Max Length: (50, (0, 0))
# Mean Length: 50.0
# Min Rate: 50
# Max Rate: 50
# Mean Rate: 50.0
# Max Age: 180
# Mean Age: 180.0
# NOT: 0
# NAND: 0
# AND: 0
# OR_N: 0
# OR: 0
# AND_N: 0
# NOR: 0
# XOR: 0
# EQU: 0
#
#
# UPDATE: 12
# Min Length: (49, (0, 11))
# Max Length: (51, (0, 1))
# Mean Length: 49.99444444444445
# Min Rate: 49
# Max Rate: 51
# Mean Rate: 49.99444444444445
# Max Age: 361
# Mean Age: 158.3
# NOT: 0
# NAND: 0
# AND: 0
# OR_N: 0
# OR: 0
# AND_N: 0
# NOR: 0
# XOR: 0
# EQU: 0
#
#
# UPDATE: 18
# Min Length: (48, (13, 6))
# Max Length: (52, (5, 8))
# Mean Length: 50.03666666666667
# Min Rate: 48
# Max Rate: 52
# Mean Rate: 50.03666666666667
# Max Age: 541
# Mean Age: 125.22555555555556
# NOT: 0
# NAND: 0
# AND: 0
# OR_N: 0
# OR: 0
# AND_N: 0
# NOR: 0
# XOR: 0
# EQU: 0
#
#
# UPDATE: 24
# Min Length: (48, (12, 7))
# Max Length: (52, (5, 8))
# Mean Length: 49.98444444444444
# Min Rate: 48
# Max Rate: 52
# Mean Rate: 49.98444444444444
# Max Age: 721
# Mean Age: 249.04777777777778
# NOT: 0
# NAND: 0
# AND: 0
# OR_N: 0
# OR: 0
# AND_N: 0
# NOR: 0
# XOR: 0
# EQU: 0
#
#
# UPDATE: 30
# Min Length: (47, (14, 11))
# Max Length: (52, (5, 7))
# Mean Length: 50.04555555555555
# Min Rate: 47
# Max Rate: 52
# Mean Rate: 50.04555555555555
# Max Age: 425
# Mean Age: 258.44
# NOT: 0
# NAND: 0
# AND: 0
# OR_N: 0
# OR: 0
# AND_N: 0
# NOR: 0
# XOR: 0
# EQU: 0
#
#
# UPDATE: 36
# Min Length: (46, (21, 23))
# Max Length: (52, (4, 7))
# Mean Length: 50.07333333333333
# Min Rate: 46
# Max Rate: 52
# Mean Rate: 50.07333333333333
# Max Age: 600
# Mean Age: 208.87666666666667
# NOT: 0
# NAND: 0
# AND: 0
# OR_N: 0
# OR: 0
# AND_N: 0
# NOR: 0
# XOR: 0
# EQU: 0
#
#
# UPDATE: 42
# Min Length: (46, (11, 24))
# Max Length: (52, (3, 6))
# Mean Length: 50.095555555555556
# Min Rate: 46
# Max Rate: 52
# Mean Rate: 50.095555555555556
# Max Age: 542
# Mean Age: 166.3411111111111
# NOT: 0
# NAND: 0
# AND: 0
# OR_N: 0
# OR: 0
# AND_N: 0
# NOR: 0
# XOR: 0
# EQU: 0
#
#
# UPDATE: 48
# Min Length: (46, (11, 24))
# Max Length: (52, (3, 6))
# Mean Length: 50.02111111111111
# Min Rate: 46
# Max Rate: 52
# Mean Rate: 50.02111111111111
# Max Age: 720
# Mean Age: 274.3677777777778
# NOT: 0
# NAND: 0
# AND: 0
# OR_N: 0
# OR: 0
# AND_N: 0
# NOR: 0
# XOR: 0
# EQU: 0
#
#
# UPDATE: 54
# Min Length: (45, (6, 18))
# Max Length: (52, (0, 14))
# Mean Length: 50.09888888888889
# Min Rate: 45
# Max Rate: 52
# Mean Rate: 50.09888888888889
# Max Age: 659
# Mean Age: 278.43888888888887
# NOT: 0
# NAND: 0
# AND: 0
# OR_N: 0
# OR: 0
# AND_N: 0
# NOR: 0
# XOR: 0
# EQU: 0
#
#
# UPDATE: 60
# Min Length: (45, (6, 18))
# Max Length: (52, (0, 14))
# Mean Length: 50.13666666666666
# Min Rate: 45
# Max Rate: 52
# Mean Rate: 50.13666666666666
# Max Age: 600
# Mean Age: 227.38555555555556
# NOT: 0
# NAND: 0
# AND: 0
# OR_N: 0
# OR: 0
# AND_N: 0
# NOR: 0
# XOR: 0
# EQU: 0
#
#
# UPDATE: 66
# Min Length: (45, (11, 25))
# Max Length: (52, (1, 14))
# Mean Length: 50.11555555555555
# Min Rate: 45
# Max Rate: 52
# Mean Rate: 50.11555555555555
# Max Age: 540
# Mean Age: 171.79333333333332
# NOT: 0
# NAND: 0
# AND: 0
# OR_N: 0
# OR: 0
# AND_N: 0
# NOR: 0
# XOR: 0
# EQU: 0
#
#
# UPDATE: 72
# Min Length: (45, (11, 25))
# Max Length: (52, (1, 14))
# Mean Length: 50.047777777777775
# Min Rate: 45
# Max Rate: 52
# Mean Rate: 50.047777777777775
# Max Age: 720
# Mean Age: 278.73777777777775
# NOT: 0
# NAND: 0
# AND: 0
# OR_N: 0
# OR: 0
# AND_N: 0
# NOR: 0
# XOR: 0
# EQU: 0
#
#
# UPDATE: 78
# Min Length: (45, (11, 25))
# Max Length: (52, (1, 17))
# Mean Length: 50.117777777777775
# Min Rate: 45
# Max Rate: 52
# Mean Rate: 50.117777777777775
# Max Age: 685
# Mean Age: 278.41777777777776
# NOT: 0
# NAND: 0
# AND: 0
# OR_N: 0
# OR: 0
# AND_N: 0
# NOR: 0
# XOR: 0
# EQU: 0
#
#
# UPDATE: 84
# Min Length: (45, (12, 17))
# Max Length: (53, (16, 18))
# Mean Length: 50.17777777777778
# Min Rate: 45
# Max Rate: 53
# Mean Rate: 50.17777777777778
# Max Age: 600
# Mean Age: 225.20222222222222
# NOT: 0
# NAND: 0
# AND: 0
# OR_N: 0
# OR: 0
# AND_N: 0
# NOR: 0
# XOR: 0
# EQU: 0
#
#
# UPDATE: 90
# Min Length: (45, (12, 17))
# Max Length: (53, (13, 18))
# Mean Length: 50.208888888888886
# Min Rate: 45
# Max Rate: 53
# Mean Rate: 50.208888888888886
# Max Age: 539
# Mean Age: 171.51222222222222
# NOT: 0
# NAND: 0
# AND: 0
# OR_N: 0
# OR: 0
# AND_N: 0
# NOR: 0
# XOR: 0
# EQU: 0
#
#
# UPDATE: 96
# Min Length: (45, (12, 17))
# Max Length: (53, (13, 18))
# Mean Length: 50.12888888888889
# Min Rate: 45
# Max Rate: 53
# Mean Rate: 50.12888888888889
# Max Age: 715
# Mean Age: 263.0211111111111
# NOT: 0
# NAND: 0
# AND: 0
# OR_N: 0
# OR: 0
# AND_N: 0
# NOR: 0
# XOR: 0
# EQU: 0
#
#
# UPDATE: 102
# Min Length: (45, (22, 6))
# Max Length: (53, (1, 19))
# Mean Length: 50.23444444444444
# Min Rate: 45
# Max Rate: 53
# Mean Rate: 50.23444444444444
# Max Age: 679
# Mean Age: 256.33666666666664
# NOT: 0
# NAND: 0
# AND: 0
# OR_N: 0
# OR: 0
# AND_N: 0
# NOR: 0
# XOR: 0
# EQU: 0
#
#
# UPDATE: 108
# Min Length: (45, (22, 6))
# Max Length: (53, (1, 20))
# Mean Length: 50.278888888888886
# Min Rate: 45
# Max Rate: 53
# Mean Rate: 50.278888888888886
# Max Age: 601
# Mean Age: 205.71555555555557
# NOT: 0
# NAND: 0
# AND: 0
# OR_N: 0
# OR: 0
# AND_N: 0
# NOR: 0
# XOR: 0
# EQU: 0
#
#
# UPDATE: 114
# Min Length: (45, (23, 15))
# Max Length: (53, (0, 20))
# Mean Length: 50.24
# Min Rate: 45
# Max Rate: 53
# Mean Rate: 50.24
# Max Age: 568
# Mean Age: 175.57777777777778
# NOT: 0
# NAND: 0
# AND: 0
# OR_N: 0
# OR: 0
# AND_N: 0
# NOR: 0
# XOR: 0
# EQU: 0
#
#
# UPDATE: 120
# Min Length: (45, (21, 15))
# Max Length: (54, (1, 21))
# Mean Length: 50.22
# Min Rate: 45
# Max Rate: 54
# Mean Rate: 50.22
# Max Age: 515
# Mean Age: 248.11666666666667
# NOT: 0
# NAND: 0
# AND: 0
# OR_N: 0
# OR: 0
# AND_N: 0
# NOR: 0
# XOR: 0
# EQU: 0
#
#
# UPDATE: 126
# Min Length: (45, (18, 10))
# Max Length: (54, (1, 21))
# Mean Length: 50.26888888888889
# Min Rate: 45
# Max Rate: 54
# Mean Rate: 50.26888888888889
# Max Age: 695
# Mean Age: 249.43333333333334
# NOT: 0
# NAND: 0
# AND: 0
# OR_N: 0
# OR: 0
# AND_N: 0
# NOR: 0
# XOR: 0
# EQU: 0
#
#
# UPDATE: 132
# Min Length: (45, (18, 10))
# Max Length: (54, (1, 21))
# Mean Length: 50.285555555555554
# Min Rate: 45
# Max Rate: 54
# Mean Rate: 50.285555555555554
# Max Age: 591
# Mean Age: 207.52777777777777
# NOT: 0
# NAND: 0
# AND: 0
# OR_N: 0
# OR: 0
# AND_N: 0
# NOR: 0
# XOR: 0
# EQU: 0
#
#
# UPDATE: 138
# Min Length: (46, (4, 25))
# Max Length: (54, (13, 17))
# Mean Length: 50.23222222222222
# Min Rate: 46
# Max Rate: 54
# Mean Rate: 50.23222222222222
# Max Age: 538
# Mean Age: 188.5211111111111
# NOT: 0
# NAND: 0
# AND: 0
# OR_N: 0
# OR: 0
# AND_N: 0
# NOR: 0
# XOR: 0
# EQU: 0
#
#
# UPDATE: 144
# Min Length: (46, (4, 23))
# Max Length: (53, (4, 9))
# Mean Length: 50.16888888888889
# Min Rate: 46
# Max Rate: 53
# Mean Rate: 50.16888888888889
# Max Age: 714
# Mean Age: 245.70666666666668
# NOT: 0
# NAND: 0
# AND: 0
# OR_N: 0
# OR: 0
# AND_N: 0
# NOR: 0
# XOR: 0
# EQU: 0
#
#
# UPDATE: 150
# Min Length: (45, (6, 17))
# Max Length: (54, (7, 0))
# Mean Length: 50.19
# Min Rate: 45
# Max Rate: 54
# Mean Rate: 50.19
# Max Age: 653
# Mean Age: 234.78333333333333
# NOT: 0
# NAND: 0
# AND: 0
# OR_N: 0
# OR: 0
# AND_N: 0
# NOR: 0
# XOR: 0
# EQU: 0
#
#
# UPDATE: 156
# Min Length: (45, (3, 16))
# Max Length: (54, (5, 0))
# Mean Length: 50.221111111111114
# Min Rate: 45
# Max Rate: 54
# Mean Rate: 50.221111111111114
# Max Age: 598
# Mean Age: 199.91444444444446
# NOT: 0
# NAND: 0
# AND: 0
# OR_N: 0
# OR: 0
# AND_N: 0
# NOR: 0
# XOR: 0
# EQU: 0
#
#
# UPDATE: 162
# Min Length: (45, (4, 5))
# Max Length: (55, (6, 2))
# Mean Length: 50.10777777777778
# Min Rate: 45
# Max Rate: 55
# Mean Rate: 50.10777777777778
# Max Age: 558
# Mean Age: 178.09666666666666
# NOT: 0
# NAND: 0
# AND: 0
# OR_N: 0
# OR: 0
# AND_N: 0
# NOR: 0
# XOR: 0
# EQU: 0
#
#
# UPDATE: 168
# Min Length: (43, (4, 6))
# Max Length: (55, (6, 2))
# Mean Length: 50.08777777777778
# Min Rate: 43
# Max Rate: 55
# Mean Rate: 50.08777777777778
# Max Age: 660
# Mean Age: 203.04666666666665
# NOT: 0
# NAND: 0
# AND: 0
# OR_N: 0
# OR: 0
# AND_N: 0
# NOR: 0
# XOR: 0
# EQU: 0
#
#
# UPDATE: 174
# Min Length: (42, (5, 6))
# Max Length: (55, (5, 2))
# Mean Length: 50.175555555555555
# Min Rate: 42
# Max Rate: 55
# Mean Rate: 50.175555555555555
# Max Age: 654
# Mean Age: 207.3711111111111
# NOT: 0
# NAND: 0
# AND: 0
# OR_N: 0
# OR: 0
# AND_N: 0
# NOR: 0
# XOR: 0
# EQU: 0
#
#
# UPDATE: 180
# Min Length: (42, (5, 6))
# Max Length: (55, (5, 2))
# Mean Length: 50.266666666666666
# Min Rate: 42
# Max Rate: 55
# Mean Rate: 50.266666666666666
# Max Age: 538
# Mean Age: 190.14777777777778
# NOT: 0
# NAND: 0
# AND: 0
# OR_N: 0
# OR: 0
# AND_N: 0
# NOR: 0
# XOR: 0
# EQU: 0
#
#
# UPDATE: 186
# Min Length: (42, (5, 6))
# Max Length: (55, (6, 3))
# Mean Length: 50.23555555555556
# Min Rate: 42
# Max Rate: 55
# Mean Rate: 50.23555555555556
# Max Age: 543
# Mean Age: 183.0088888888889
# NOT: 0
# NAND: 0
# AND: 0
# OR_N: 0
# OR: 0
# AND_N: 0
# NOR: 0
# XOR: 0
# EQU: 0
#
#
# UPDATE: 192
# Min Length: (45, (0, 26))
# Max Length: (55, (6, 3))
# Mean Length: 50.284444444444446
# Min Rate: 45
# Max Rate: 55
# Mean Rate: 50.284444444444446
# Max Age: 712
# Mean Age: 201.05777777777777
# NOT: 0
# NAND: 0
# AND: 0
# OR_N: 0
# OR: 0
# AND_N: 0
# NOR: 0
# XOR: 0
# EQU: 0
#
#
# UPDATE: 198
# Min Length: (43, (24, 8))
# Max Length: (55, (6, 4))
# Mean Length: 50.39888888888889
# Min Rate: 43
# Max Rate: 55
# Mean Rate: 50.39888888888889
# Max Age: 651
# Mean Age: 202.22222222222223
# NOT: 0
# NAND: 0
# AND: 0
# OR_N: 0
# OR: 0
# AND_N: 0
# NOR: 0
# XOR: 0
# EQU: 0
# UPDATE: 204
# Min Length: (43, (24, 8))
# Max Length: (55, (7, 3))
# Mean Length: 50.42
# Min Rate: 43
# Max Rate: 55
# Mean Rate: 50.42
# Max Age: 580
# Mean Age: 186.42888888888888
# NOT: 0
# NAND: 0
# AND: 0
# OR_N: 0
# OR: 0
# AND_N: 0
# NOR: 0
# XOR: 0
# EQU: 0
#
#
# UPDATE: 210
# Min Length: (43, (24, 8))
# Max Length: (55, (7, 3))
# Mean Length: 50.443333333333335
# Min Rate: 43
# Max Rate: 55
# Mean Rate: 50.443333333333335
# Max Age: 577
# Mean Age: 186.84555555555556
# NOT: 0
# NAND: 0
# AND: 0
# OR_N: 0
# OR: 0
# AND_N: 0
# NOR: 0
# XOR: 0
# EQU: 0
#
#
# UPDATE: 216
# Min Length: (46, (5, 9))
# Max Length: (55, (6, 4))
# Mean Length: 50.41777777777778
# Min Rate: 46
# Max Rate: 55
# Mean Rate: 50.41777777777778
# Max Age: 559
# Mean Age: 198.74444444444444
# NOT: 0
# NAND: 0
# AND: 0
# OR_N: 0
# OR: 0
# AND_N: 0
# NOR: 0
# XOR: 0
# EQU: 0
#
#
# UPDATE: 222
# Min Length: (45, (0, 29))
# Max Length: (55, (4, 15))
# Mean Length: 50.52444444444444
# Min Rate: 45
# Max Rate: 55
# Mean Rate: 50.52444444444444
# Max Age: 653
# Mean Age: 185.48777777777778
# NOT: 0
# NAND: 0
# AND: 0
# OR_N: 0
# OR: 0
# AND_N: 0
# NOR: 0
# XOR: 0
# EQU: 0
#
#
# UPDATE: 228
# Min Length: (45, (0, 28))
# Max Length: (55, (4, 15))
# Mean Length: 50.55444444444444
# Min Rate: 45
# Max Rate: 55
# Mean Rate: 50.55444444444444
# Max Age: 656
# Mean Age: 176.84666666666666
# NOT: 0
# NAND: 0
# AND: 0
# OR_N: 0
# OR: 0
# AND_N: 0
# NOR: 0
# XOR: 0
# EQU: 0
#
#
# UPDATE: 234
# Min Length: (45, (26, 7))
# Max Length: (55, (4, 15))
# Mean Length: 50.63444444444445
# Min Rate: 45
# Max Rate: 55
# Mean Rate: 50.63444444444445
# Max Age: 604
# Mean Age: 172.17666666666668
# NOT: 0
# NAND: 0
# AND: 0
# OR_N: 0
# OR: 0
# AND_N: 0
# NOR: 0
# XOR: 0
# EQU: 0
#
#
# UPDATE: 240
# Min Length: (45, (24, 4))
# Max Length: (56, (6, 16))
# Mean Length: 50.65888888888889
# Min Rate: 45
# Max Rate: 56
# Mean Rate: 50.65888888888889
# Max Age: 622
# Mean Age: 182.30777777777777
# NOT: 0
# NAND: 0
# AND: 0
# OR_N: 0
# OR: 0
# AND_N: 0
# NOR: 0
# XOR: 0
# EQU: 0
#
#
# UPDATE: 246
# Min Length: (45, (1, 12))
# Max Length: (56, (6, 16))
# Mean Length: 50.727777777777774
# Min Rate: 45
# Max Rate: 56
# Mean Rate: 50.727777777777774
# Max Age: 643
# Mean Age: 181.45222222222222
# NOT: 0
# NAND: 0
# AND: 0
# OR_N: 0
# OR: 0
# AND_N: 0
# NOR: 0
# XOR: 0
# EQU: 0
#
#
# UPDATE: 252
# Min Length: (43, (21, 10))
# Max Length: (56, (5, 15))
# Mean Length: 50.772222222222226
# Min Rate: 43
# Max Rate: 56
# Mean Rate: 50.772222222222226
# Max Age: 572
# Mean Age: 181.68333333333334
# NOT: 0
# NAND: 0
# AND: 0
# OR_N: 0
# OR: 0
# AND_N: 0
# NOR: 0
# XOR: 0
# EQU: 0
#
#
# UPDATE: 258
# Min Length: (43, (21, 10))
# Max Length: (56, (5, 14))
# Mean Length: 50.80555555555556
# Min Rate: 43
# Max Rate: 56
# Mean Rate: 50.80555555555556
# Max Age: 644
# Mean Age: 171.88222222222223
# NOT: 0
# NAND: 0
# AND: 0
# OR_N: 0
# OR: 0
# AND_N: 0
# NOR: 0
# XOR: 0
# EQU: 0
#
#
# UPDATE: 264
# Min Length: (44, (26, 26))
# Max Length: (56, (6, 13))
# Mean Length: 50.931111111111115
# Min Rate: 44
# Max Rate: 56
# Mean Rate: 50.931111111111115
# Max Age: 627
# Mean Age: 169.03
# NOT: 0
# NAND: 0
# AND: 0
# OR_N: 0
# OR: 0
# AND_N: 0
# NOR: 0
# XOR: 0
# EQU: 0
#
#
# UPDATE: 270
# Min Length: (44, (1, 6))
# Max Length: (56, (6, 13))
# Mean Length: 50.95444444444445
# Min Rate: 44
# Max Rate: 56
# Mean Rate: 50.95444444444445
# Max Age: 465
# Mean Age: 164.48555555555555
# NOT: 0
# NAND: 0
# AND: 0
# OR_N: 0
# OR: 0
# AND_N: 0
# NOR: 0
# XOR: 0
# EQU: 0
#
#
# UPDATE: 276
# Min Length: (44, (27, 18))
# Max Length: (56, (6, 14))
# Mean Length: 51.026666666666664
# Min Rate: 44
# Max Rate: 56
# Mean Rate: 51.026666666666664
# Max Age: 570
# Mean Age: 155.63888888888889
# NOT: 0
# NAND: 0
# AND: 0
# OR_N: 0
# OR: 0
# AND_N: 0
# NOR: 0
# XOR: 0
# EQU: 0
#
#
# UPDATE: 282
# Min Length: (44, (27, 17))
# Max Length: (57, (6, 14))
# Mean Length: 51.065555555555555
# Min Rate: 44
# Max Rate: 57
# Mean Rate: 51.065555555555555
# Max Age: 530
# Mean Age: 161.19333333333333
# NOT: 0
# NAND: 0
# AND: 0
# OR_N: 0
# OR: 0
# AND_N: 0
# NOR: 0
# XOR: 0
# EQU: 0
#
#
# UPDATE: 288
# Min Length: (44, (21, 19))
# Max Length: (55, (0, 10))
# Mean Length: 51.086666666666666
# Min Rate: 44
# Max Rate: 55
# Mean Rate: 51.086666666666666
# Max Age: 591
# Mean Age: 154.45666666666668
# NOT: 0
# NAND: 0
# AND: 0
# OR_N: 0
# OR: 0
# AND_N: 0
# NOR: 0
# XOR: 0
# EQU: 0
#
#
# UPDATE: 294
# Min Length: (44, (21, 19))
# Max Length: (55, (1, 10))
# Mean Length: 51.11
# Min Rate: 44
# Max Rate: 55
# Mean Rate: 51.11
# Max Age: 583
# Mean Age: 145.05777777777777
# NOT: 0
# NAND: 0
# AND: 0
# OR_N: 0
# OR: 0
# AND_N: 0
# NOR: 0
# XOR: 0
# EQU: 0
#
#
# UPDATE: 300
# Min Length: (44, (27, 22))
# Max Length: (55, (1, 21))
# Mean Length: 51.06444444444445
# Min Rate: 44
# Max Rate: 55
# Mean Rate: 51.06444444444445
# Max Age: 442
# Mean Age: 141.2511111111111
# NOT: 0
# NAND: 0
# AND: 0
# OR_N: 0
# OR: 0
# AND_N: 0
# NOR: 0
# XOR: 0
# EQU: 0
#
#
# UPDATE: 306
# Min Length: (45, (4, 16))
# Max Length: (55, (2, 18))
# Mean Length: 51.10777777777778
# Min Rate: 45
# Max Rate: 55
# Mean Rate: 51.10777777777778
# Max Age: 553
# Mean Age: 146.15222222222224
# NOT: 0
# NAND: 0
# AND: 0
# OR_N: 0
# OR: 0
# AND_N: 0
# NOR: 0
# XOR: 0
# EQU: 0
#
#
# UPDATE: 312
# Min Length: (44, (28, 3))
# Max Length: (56, (11, 15))
# Mean Length: 51.14111111111111
# Min Rate: 44
# Max Rate: 56
# Mean Rate: 51.14111111111111
# Max Age: 409
# Mean Age: 146.76777777777778
# NOT: 0
# NAND: 0
# AND: 0
# OR_N: 0
# OR: 0
# AND_N: 0
# NOR: 0
# XOR: 0
# EQU: 0
#
#
# UPDATE: 318
# Min Length: (44, (28, 3))
# Max Length: (56, (9, 25))
# Mean Length: 51.21222222222222
# Min Rate: 44
# Max Rate: 56
# Mean Rate: 51.21222222222222
# Max Age: 421
# Mean Age: 145.57666666666665
# NOT: 0
# NAND: 0
# AND: 0
# OR_N: 0
# OR: 0
# AND_N: 0
# NOR: 0
# XOR: 0
# EQU: 0
#
#
# UPDATE: 324
# Min Length: (45, (4, 20))
# Max Length: (56, (7, 15))
# Mean Length: 51.26777777777778
# Min Rate: 45
# Max Rate: 56
# Mean Rate: 51.26777777777778
# Max Age: 424
# Mean Age: 141.62666666666667
# NOT: 0
# NAND: 0
# AND: 0
# OR_N: 0
# OR: 0
# AND_N: 0
# NOR: 0
# XOR: 0
# EQU: 0
#
#
# UPDATE: 330
# Min Length: (44, (1, 18))
# Max Length: (56, (7, 15))
# Mean Length: 51.39333333333333
# Min Rate: 44
# Max Rate: 56
# Mean Rate: 51.39333333333333
# Max Age: 404
# Mean Age: 144.9388888888889
# NOT: 0
# NAND: 0
# AND: 0
# OR_N: 0
# OR: 0
# AND_N: 0
# NOR: 0
# XOR: 0
# EQU: 0
#
#
# UPDATE: 336
# Min Length: (44, (0, 19))
# Max Length: (56, (7, 14))
# Mean Length: 51.486666666666665
# Min Rate: 44
# Max Rate: 56
# Mean Rate: 51.486666666666665
# Max Age: 381
# Mean Age: 147.59666666666666
# NOT: 0
# NAND: 0
# AND: 0
# OR_N: 0
# OR: 0
# AND_N: 0
# NOR: 0
# XOR: 0
# EQU: 0
#
#
# UPDATE: 342
# Min Length: (44, (5, 22))
# Max Length: (56, (6, 15))
# Mean Length: 51.51111111111111
# Min Rate: 44
# Max Rate: 56
# Mean Rate: 51.51111111111111
# Max Age: 392
# Mean Age: 146.95333333333335
# NOT: 0
# NAND: 0
# AND: 0
# OR_N: 0
# OR: 0
# AND_N: 0
# NOR: 0
# XOR: 0
# EQU: 0
#
#
# UPDATE: 348
# Min Length: (44, (8, 2))
# Max Length: (56, (5, 13))
# Mean Length: 51.605555555555554
# Min Rate: 44
# Max Rate: 56
# Mean Rate: 51.605555555555554
# Max Age: 456
# Mean Age: 135.5911111111111
# NOT: 0
# NAND: 0
# AND: 0
# OR_N: 0
# OR: 0
# AND_N: 0
# NOR: 0
# XOR: 0
# EQU: 0
#
#
# UPDATE: 354
# Min Length: (44, (8, 2))
# Max Length: (57, (10, 21))
# Mean Length: 51.79333333333334
# Min Rate: 44
# Max Rate: 57
# Mean Rate: 51.79333333333334
# Max Age: 444
# Mean Age: 137.38666666666666
# NOT: 0
# NAND: 0
# AND: 0
# OR_N: 0
# OR: 0
# AND_N: 0
# NOR: 0
# XOR: 0
# EQU: 0
#
#
# UPDATE: 360
# Min Length: (44, (10, 18))
# Max Length: (57, (12, 27))
# Mean Length: 51.94111111111111
# Min Rate: 44
# Max Rate: 57
# Mean Rate: 51.94111111111111
# Max Age: 477
# Mean Age: 139.4622222222222
# NOT: 0
# NAND: 0
# AND: 0
# OR_N: 0
# OR: 0
# AND_N: 0
# NOR: 0
# XOR: 0
# EQU: 0
#
#
# UPDATE: 366
# Min Length: (46, (17, 16))
# Max Length: (58, (22, 24))
# Mean Length: 52.12888888888889
# Min Rate: 46
# Max Rate: 58
# Mean Rate: 52.12888888888889
# Max Age: 548
# Mean Age: 138.01333333333332
# NOT: 0
# NAND: 0
# AND: 0
# OR_N: 0
# OR: 0
# AND_N: 0
# NOR: 0
# XOR: 0
# EQU: 0
#
#
# UPDATE: 372
# Min Length: (45, (3, 0))
# Max Length: (58, (20, 25))
# Mean Length: 52.254444444444445
# Min Rate: 45
# Max Rate: 58
# Mean Rate: 52.254444444444445
# Max Age: 483
# Mean Age: 131.51777777777778
# NOT: 0
# NAND: 0
# AND: 0
# OR_N: 0
# OR: 0
# AND_N: 0
# NOR: 0
# XOR: 0
# EQU: 0
#
#
# UPDATE: 378
# Min Length: (45, (25, 17))
# Max Length: (58, (21, 23))
# Mean Length: 52.64222222222222
# Min Rate: 45
# Max Rate: 58
# Mean Rate: 52.64222222222222
# Max Age: 563
# Mean Age: 132.28444444444443
# NOT: 0
# NAND: 0
# AND: 0
# OR_N: 0
# OR: 0
# AND_N: 0
# NOR: 0
# XOR: 0
# EQU: 0
#
#
# UPDATE: 384
# Min Length: (46, (3, 20))
# Max Length: (58, (22, 22))
# Mean Length: 52.95777777777778
# Min Rate: 46
# Max Rate: 58
# Mean Rate: 52.95777777777778
# Max Age: 605
# Mean Age: 140.37333333333333
# NOT: 0
# NAND: 0
# AND: 0
# OR_N: 0
# OR: 0
# AND_N: 0
# NOR: 0
# XOR: 0
# EQU: 0
#
#
# UPDATE: 390
# Min Length: (46, (22, 27))
# Max Length: (58, (21, 22))
# Mean Length: 53.41222222222222
# Min Rate: 46
# Max Rate: 58
# Mean Rate: 53.41222222222222
# Max Age: 736
# Mean Age: 145.1211111111111
# NOT: 0
# NAND: 0
# AND: 0
# OR_N: 0
# OR: 0
# AND_N: 0
# NOR: 0
# XOR: 0
# EQU: 0
# UPDATE: 396
# Min Length: (45, (27, 7))
# Max Length: (58, (9, 28))
# Mean Length: 53.87777777777778
# Min Rate: 45
# Max Rate: 58
# Mean Rate: 53.87777777777778
# Max Age: 582
# Mean Age: 143.26777777777778
# NOT: 0
# NAND: 0
# AND: 0
# OR_N: 0
# OR: 0
# AND_N: 0
# NOR: 0
# XOR: 0
# EQU: 0
#
#
# UPDATE: 402
# Min Length: (45, (28, 6))
# Max Length: (58, (9, 28))
# Mean Length: 54.336666666666666
# Min Rate: 45
# Max Rate: 58
# Mean Rate: 54.336666666666666
# Max Age: 678
# Mean Age: 151.36333333333334
# NOT: 0
# NAND: 0
# AND: 0
# OR_N: 0
# OR: 0
# AND_N: 0
# NOR: 0
# XOR: 0
# EQU: 0
#
#
# UPDATE: 408
# Min Length: (47, (29, 8))
# Max Length: (58, (4, 11))
# Mean Length: 54.83111111111111
# Min Rate: 47
# Max Rate: 58
# Mean Rate: 54.83111111111111
# Max Age: 722
# Mean Age: 149.02333333333334
# NOT: 0
# NAND: 0
# AND: 0
# OR_N: 0
# OR: 0
# AND_N: 0
# NOR: 0
# XOR: 0
# EQU: 0
#
#
# UPDATE: 414
# Min Length: (48, (5, 24))
# Max Length: (58, (1, 13))
# Mean Length: 55.60777777777778
# Min Rate: 48
# Max Rate: 58
# Mean Rate: 55.60777777777778
# Max Age: 692
# Mean Age: 135.3411111111111
# NOT: 0
# NAND: 0
# AND: 0
# OR_N: 0
# OR: 0
# AND_N: 0
# NOR: 0
# XOR: 0
# EQU: 0
#
#
# UPDATE: 420
# Min Length: (48, (3, 23))
# Max Length: (58, (0, 11))
# Mean Length: 56.123333333333335
# Min Rate: 48
# Max Rate: 58
# Mean Rate: 56.123333333333335
# Max Age: 767
# Mean Age: 149.3011111111111
# NOT: 0
# NAND: 0
# AND: 0
# OR_N: 0
# OR: 0
# AND_N: 0
# NOR: 0
# XOR: 0
# EQU: 0
#
#
# UPDATE: 426
# Min Length: (48, (2, 24))
# Max Length: (58, (0, 6))
# Mean Length: 56.62
# Min Rate: 48
# Max Rate: 58
# Mean Rate: 56.62
# Max Age: 839
# Mean Age: 162.82555555555555
# NOT: 0
# NAND: 0
# AND: 0
# OR_N: 0
# OR: 0
# AND_N: 0
# NOR: 0
# XOR: 0
# EQU: 0
#
#
# UPDATE: 432
# Min Length: (48, (4, 24))
# Max Length: (59, (4, 9))
# Mean Length: 57.13333333333333
# Min Rate: 48
# Max Rate: 59
# Mean Rate: 57.13333333333333
# Max Age: 1019
# Mean Age: 180.67555555555555
# NOT: 0
# NAND: 0
# AND: 0
# OR_N: 0
# OR: 0
# AND_N: 0
# NOR: 0
# XOR: 0
# EQU: 0
#
#
# UPDATE: 438
# Min Length: (51, (18, 29))
# Max Length: (59, (0, 2))
# Mean Length: 57.733333333333334
# Min Rate: 51
# Max Rate: 59
# Mean Rate: 57.733333333333334
# Max Age: 1109
# Mean Age: 171.80666666666667
# NOT: 0
# NAND: 0
# AND: 0
# OR_N: 0
# OR: 0
# AND_N: 0
# NOR: 0
# XOR: 0
# EQU: 0
#
#
# UPDATE: 444
# Min Length: (54, (0, 26))
# Max Length: (59, (1, 9))
# Mean Length: 58.06111111111111
# Min Rate: 54
# Max Rate: 59
# Mean Rate: 58.06111111111111
# Max Age: 1256
# Mean Age: 174.08555555555554
# NOT: 0
# NAND: 0
# AND: 0
# OR_N: 0
# OR: 0
# AND_N: 0
# NOR: 0
# XOR: 0
# EQU: 0
#
#
# UPDATE: 450
# Min Length: (57, (11, 14))
# Max Length: (59, (2, 0))
# Mean Length: 58.336666666666666
# Min Rate: 57
# Max Rate: 59
# Mean Rate: 58.336666666666666
# Max Age: 1447
# Mean Age: 169.14444444444445
# NOT: 0
# NAND: 0
# AND: 0
# OR_N: 0
# OR: 0
# AND_N: 0
# NOR: 0
# XOR: 0
# EQU: 0
#
#
# UPDATE: 456
# Min Length: (57, (5, 14))
# Max Length: (60, (9, 20))
# Mean Length: 58.62555555555556
# Min Rate: 57
# Max Rate: 60
# Mean Rate: 58.62555555555556
# Max Age: 1163
# Mean Age: 164.26777777777778
# NOT: 0
# NAND: 0
# AND: 0
# OR_N: 0
# OR: 0
# AND_N: 0
# NOR: 0
# XOR: 0
# EQU: 0
#
#
# UPDATE: 462
# Min Length: (58, (0, 1))
# Max Length: (60, (1, 3))
# Mean Length: 58.87
# Min Rate: 58
# Max Rate: 60
# Mean Rate: 58.87
# Max Age: 896
# Mean Age: 169.05555555555554
# NOT: 0
# NAND: 0
# AND: 0
# OR_N: 0
# OR: 0
# AND_N: 0
# NOR: 0
# XOR: 0
# EQU: 0
#
#
# UPDATE: 468
# Min Length: (58, (0, 20))
# Max Length: (61, (5, 0))
# Mean Length: 59.15
# Min Rate: 58
# Max Rate: 61
# Mean Rate: 59.15
# Max Age: 919
# Mean Age: 176.7
# NOT: 0
# NAND: 0
# AND: 0
# OR_N: 0
# OR: 0
# AND_N: 0
# NOR: 0
# XOR: 0
# EQU: 0
#
#
# UPDATE: 474
# Min Length: (58, (0, 21))
# Max Length: (61, (0, 2))
# Mean Length: 59.492222222222225
# Min Rate: 58
# Max Rate: 61
# Mean Rate: 59.492222222222225
# Max Age: 1109
# Mean Age: 168.98777777777778
# NOT: 1
# NAND: 0
# AND: 0
# OR_N: 0
# OR: 0
# AND_N: 0
# NOR: 0
# XOR: 0
# EQU: 0
#
#
# UPDATE: 480
# Min Length: (59, (0, 8))
# Max Length: (61, (0, 0))
# Mean Length: 59.85777777777778
# Min Rate: 59
# Max Rate: 120
# Mean Rate: 60.12444444444444
# Max Age: 1300
# Mean Age: 161.23555555555555
# NOT: 3
# NAND: 0
# AND: 0
# OR_N: 0
# OR: 0
# AND_N: 0
# NOR: 0
# XOR: 0
# EQU: 0
#
#
# UPDATE: 486
# Min Length: (59, (0, 23))
# Max Length: (61, (0, 0))
# Mean Length: 60.21888888888889
# Min Rate: 59
# Max Rate: 120
# Mean Rate: 61.15111111111111
# Max Age: 965
# Mean Age: 158.3322222222222
# NOT: 12
# NAND: 0
# AND: 0
# OR_N: 0
# OR: 0
# AND_N: 0
# NOR: 0
# XOR: 0
# EQU: 0
#
#
# UPDATE: 492
# Min Length: (58, (14, 25))
# Max Length: (62, (15, 27))
# Mean Length: 60.50555555555555
# Min Rate: 58
# Max Rate: 120
# Mean Rate: 63.17
# Max Age: 1367
# Mean Age: 163.00333333333333
# NOT: 31
# NAND: 0
# AND: 0
# OR_N: 0
# OR: 0
# AND_N: 0
# NOR: 0
# XOR: 0
# EQU: 0
#
#
# UPDATE: 498
# Min Length: (58, (9, 4))
# Max Length: (62, (0, 17))
# Mean Length: 60.681111111111115
# Min Rate: 58
# Max Rate: 122
# Mean Rate: 67.34333333333333
# Max Age: 1358
# Mean Age: 177.4777777777778
# NOT: 84
# NAND: 0
# AND: 0
# OR_N: 0
# OR: 0
# AND_N: 0
# NOR: 0
# XOR: 0
# EQU: 0
#
#
# UPDATE: 504
# Min Length: (57, (19, 22))
# Max Length: (62, (0, 19))
# Mean Length: 60.62
# Min Rate: 58
# Max Rate: 122
# Mean Rate: 77.41888888888889
# Max Age: 1296
# Mean Age: 174.91333333333333
# NOT: 152
# NAND: 0
# AND: 0
# OR_N: 0
# OR: 0
# AND_N: 0
# NOR: 0
# XOR: 0
# EQU: 0
#
#
# UPDATE: 510
# Min Length: (57, (13, 23))
# Max Length: (62, (4, 28))
# Mean Length: 60.43333333333333
# Min Rate: 58
# Max Rate: 124
# Mean Rate: 87.56888888888889
# Max Age: 826
# Mean Age: 187.04222222222222
# NOT: 362
# NAND: 0
# AND: 0
# OR_N: 0
# OR: 0
# AND_N: 0
# NOR: 0
# XOR: 0
# EQU: 0
#
#
# UPDATE: 516
# Min Length: (57, (11, 24))
# Max Length: (62, (0, 29))
# Mean Length: 60.275555555555556
# Min Rate: 58
# Max Rate: 124
# Mean Rate: 98.14888888888889
# Max Age: 924
# Mean Age: 200.34444444444443
# NOT: 468
# NAND: 0
# AND: 0
# OR_N: 0
# OR: 0
# AND_N: 0
# NOR: 0
# XOR: 0
# EQU: 0
#
#
# UPDATE: 522
# Min Length: (57, (2, 9))
# Max Length: (62, (2, 2))
# Mean Length: 60.10333333333333
# Min Rate: 57
# Max Rate: 124
# Mean Rate: 107.45555555555555
# Max Age: 558
# Mean Age: 140.77
# NOT: 463
# NAND: 0
# AND: 0
# OR_N: 0
# OR: 0
# AND_N: 0
# NOR: 0
# XOR: 0
# EQU: 0
#
#
# UPDATE: 528
# Min Length: (57, (0, 17))
# Max Length: (62, (0, 4))
# Mean Length: 60.06666666666667
# Min Rate: 57
# Max Rate: 124
# Mean Rate: 109.23333333333333
# Max Age: 542
# Mean Age: 129.92555555555555
# NOT: 578
# NAND: 0
# AND: 0
# OR_N: 0
# OR: 0
# AND_N: 0
# NOR: 0
# XOR: 0
# EQU: 0
#
#
# UPDATE: 534
# Min Length: (57, (5, 12))
# Max Length: (62, (1, 17))
# Mean Length: 60.044444444444444
# Min Rate: 57
# Max Rate: 124
# Mean Rate: 111.68888888888888
# Max Age: 450
# Mean Age: 134.53333333333333
# NOT: 615
# NAND: 0
# AND: 0
# OR_N: 0
# OR: 0
# AND_N: 0
# NOR: 0
# XOR: 0
# EQU: 0
#
#
# UPDATE: 540
# Min Length: (56, (7, 10))
# Max Length: (62, (0, 12))
# Mean Length: 60.04
# Min Rate: 56
# Max Rate: 124
# Mean Rate: 112.50444444444445
# Max Age: 452
# Mean Age: 147.12333333333333
# NOT: 658
# NAND: 0
# AND: 0
# OR_N: 0
# OR: 0
# AND_N: 0
# NOR: 0
# XOR: 0
# EQU: 0
#
#
# UPDATE: 546
# Min Length: (56, (10, 7))
# Max Length: (62, (8, 28))
# Mean Length: 60.04222222222222
# Min Rate: 56
# Max Rate: 124
# Mean Rate: 113.17777777777778
# Max Age: 490
# Mean Age: 155.65666666666667
# NOT: 678
# NAND: 0
# AND: 0
# OR_N: 0
# OR: 0
# AND_N: 0
# NOR: 0
# XOR: 0
# EQU: 0
#
#
# UPDATE: 552
# Min Length: (56, (18, 8))
# Max Length: (63, (22, 0))
# Mean Length: 60.034444444444446
# Min Rate: 57
# Max Rate: 126
# Mean Rate: 113.02222222222223
# Max Age: 586
# Mean Age: 161.98111111111112
# NOT: 673
# NAND: 0
# AND: 0
# OR_N: 0
# OR: 0
# AND_N: 0
# NOR: 0
# XOR: 0
# EQU: 0
#
#
# UPDATE: 558
# Min Length: (56, (11, 6))
# Max Length: (62, (3, 20))
# Mean Length: 60.07666666666667
# Min Rate: 57
# Max Rate: 124
# Mean Rate: 111.7611111111111
# Max Age: 702
# Mean Age: 174.24444444444444
# NOT: 657
# NAND: 0
# AND: 0
# OR_N: 0
# OR: 0
# AND_N: 0
# NOR: 0
# XOR: 0
# EQU: 0
#
#
# UPDATE: 564
# Min Length: (56, (20, 10))
# Max Length: (63, (27, 17))
# Mean Length: 60.10777777777778
# Min Rate: 56
# Max Rate: 126
# Mean Rate: 110.83444444444444
# Max Age: 604
# Mean Age: 185.72666666666666
# NOT: 658
# NAND: 0
# AND: 0
# OR_N: 0
# OR: 0
# AND_N: 0
# NOR: 0
# XOR: 0
# EQU: 0
#
#
# UPDATE: 570
# Min Length: (56, (20, 7))
# Max Length: (63, (17, 19))
# Mean Length: 60.11555555555555
# Min Rate: 56
# Max Rate: 126
# Mean Rate: 112.23777777777778
# Max Age: 510
# Mean Age: 189.5611111111111
# NOT: 655
# NAND: 0
# AND: 0
# OR_N: 0
# OR: 0
# AND_N: 0
# NOR: 0
# XOR: 0
# EQU: 0
#
#
# UPDATE: 576
# Min Length: (57, (4, 18))
# Max Length: (64, (16, 12))
# Mean Length: 60.14888888888889
# Min Rate: 57
# Max Rate: 126
# Mean Rate: 113.29222222222222
# Max Age: 546
# Mean Age: 185.89222222222222
# NOT: 636
# NAND: 0
# AND: 0
# OR_N: 0
# OR: 0
# AND_N: 0
# NOR: 0
# XOR: 0
# EQU: 0
#
#
# UPDATE: 582
# Min Length: (57, (5, 5))
# Max Length: (64, (20, 12))
# Mean Length: 60.14222222222222
# Min Rate: 57
# Max Rate: 126
# Mean Rate: 112.61555555555556
# Max Age: 544
# Mean Age: 167.17111111111112
# NOT: 610
# NAND: 0
# AND: 0
# OR_N: 0
# OR: 0
# AND_N: 0
# NOR: 0
# XOR: 0
# EQU: 0
# UPDATE: 588
# Min Length: (56, (6, 19))
# Max Length: (63, (28, 14))
# Mean Length: 60.093333333333334
# Min Rate: 56
# Max Rate: 126
# Mean Rate: 112.53888888888889
# Max Age: 584
# Mean Age: 161.0288888888889
# NOT: 595
# NAND: 0
# AND: 0
# OR_N: 0
# OR: 0
# AND_N: 0
# NOR: 0
# XOR: 0
# EQU: 0
#
#
# UPDATE: 594
# Min Length: (56, (27, 16))
# Max Length: (63, (21, 15))
# Mean Length: 60.114444444444445
# Min Rate: 57
# Max Rate: 126
# Mean Rate: 112.38
# Max Age: 478
# Mean Age: 150.71777777777777
# NOT: 586
# NAND: 0
# AND: 0
# OR_N: 0
# OR: 0
# AND_N: 0
# NOR: 0
# XOR: 0
# EQU: 0
#
#
# UPDATE: 600
# Min Length: (56, (11, 22))
# Max Length: (63, (22, 15))
# Mean Length: 60.126666666666665
# Min Rate: 57
# Max Rate: 126
# Mean Rate: 113.26555555555555
# Max Age: 594
# Mean Age: 148.02
# NOT: 588
# NAND: 0
# AND: 0
# OR_N: 0
# OR: 0
# AND_N: 0
# NOR: 0
# XOR: 0
# EQU: 0
#
#
# UPDATE: 606
# Min Length: (56, (11, 22))
# Max Length: (63, (12, 12))
# Mean Length: 60.12111111111111
# Min Rate: 57
# Max Rate: 126
# Mean Rate: 113.71444444444444
# Max Age: 462
# Mean Age: 139.85888888888888
# NOT: 603
# NAND: 0
# AND: 0
# OR_N: 0
# OR: 0
# AND_N: 0
# NOR: 0
# XOR: 0
# EQU: 0
#
#
# UPDATE: 612
# Min Length: (56, (7, 20))
# Max Length: (63, (10, 14))
# Mean Length: 60.175555555555555
# Min Rate: 57
# Max Rate: 126
# Mean Rate: 113.67333333333333
# Max Age: 520
# Mean Age: 141.26777777777778
# NOT: 633
# NAND: 0
# AND: 0
# OR_N: 0
# OR: 0
# AND_N: 0
# NOR: 0
# XOR: 0
# EQU: 0
#
#
# UPDATE: 618
# Min Length: (56, (26, 3))
# Max Length: (64, (11, 19))
# Mean Length: 60.15555555555556
# Min Rate: 57
# Max Rate: 128
# Mean Rate: 112.77222222222223
# Max Age: 438
# Mean Age: 145.44
# NOT: 634
# NAND: 0
# AND: 0
# OR_N: 0
# OR: 0
# AND_N: 0
# NOR: 0
# XOR: 0
# EQU: 0
#
#
# UPDATE: 624
# Min Length: (54, (24, 4))
# Max Length: (63, (3, 24))
# Mean Length: 60.17111111111111
# Min Rate: 57
# Max Rate: 126
# Mean Rate: 111.59777777777778
# Max Age: 502
# Mean Age: 151.95111111111112
# NOT: 624
# NAND: 0
# AND: 0
# OR_N: 0
# OR: 0
# AND_N: 0
# NOR: 0
# XOR: 0
# EQU: 0
#
#
# Reacting on nor
# Notifying experiment of function_IO
# Notifying experiment of function_IO
# Notifying experiment of function_IO
# Notifying experiment of function_IO
# Notifying experiment of function_IO
# Notifying experiment of function_IO
# Notifying experiment of function_IO
# Notifying experiment of function_IO
# Notifying experiment of function_IO
# Notifying experiment of function_IO
# Reacting on nor
# Notifying experiment of function_IO
# Notifying experiment of function_IO
# Notifying experiment of function_IO
# Notifying experiment of function_IO
# Notifying experiment of function_IO
# Notifying experiment of function_IO
# Notifying experiment of function_IO
# Notifying experiment of function_IO
# Notifying experiment of function_IO
# Notifying experiment of function_IO
# UPDATE: 630
# Min Length: (54, (23, 4))
# Max Length: (63, (0, 29))
# Mean Length: 60.184444444444445
# Min Rate: 56
# Max Rate: 126
# Mean Rate: 111.10111111111111
# Max Age: 492
# Mean Age: 156.01
# NOT: 619
# NAND: 0
# AND: 0
# OR_N: 0
# OR: 0
# AND_N: 0
# NOR: 1
# XOR: 0
# EQU: 0
#
#
# UPDATE: 636
# Min Length: (54, (27, 9))
# Max Length: (64, (23, 29))
# Mean Length: 60.22888888888889
# Min Rate: 56
# Max Rate: 126
# Mean Rate: 110.60777777777778
# Max Age: 536
# Mean Age: 159.69666666666666
# NOT: 632
# NAND: 0
# AND: 0
# OR_N: 0
# OR: 0
# AND_N: 0
# NOR: 1
# XOR: 0
# EQU: 0
#
#
# UPDATE: 642
# Min Length: (56, (11, 29))
# Max Length: (64, (29, 28))
# Mean Length: 60.20333333333333
# Min Rate: 57
# Max Rate: 126
# Mean Rate: 111.49
# Max Age: 562
# Mean Age: 169.89888888888888
# NOT: 629
# NAND: 0
# AND: 0
# OR_N: 0
# OR: 0
# AND_N: 0
# NOR: 0
# XOR: 0
# EQU: 0
#
#
# UPDATE: 648
# Min Length: (54, (14, 23))
# Max Length: (63, (4, 4))
# Mean Length: 60.17111111111111
# Min Rate: 54
# Max Rate: 126
# Mean Rate: 111.65
# Max Age: 514
# Mean Age: 164.18444444444444
# NOT: 608
# NAND: 0
# AND: 0
# OR_N: 0
# OR: 0
# AND_N: 0
# NOR: 0
# XOR: 0
# EQU: 0
#
#
# UPDATE: 654
# Min Length: (54, (14, 28))
# Max Length: (63, (12, 13))
# Mean Length: 60.17333333333333
# Min Rate: 54
# Max Rate: 126
# Mean Rate: 113.00888888888889
# Max Age: 542
# Mean Age: 149.9177777777778
# NOT: 582
# NAND: 0
# AND: 0
# OR_N: 0
# OR: 0
# AND_N: 0
# NOR: 0
# XOR: 0
# EQU: 0
#
#
# UPDATE: 660
# Min Length: (56, (21, 2))
# Max Length: (63, (12, 0))
# Mean Length: 60.21666666666667
# Min Rate: 57
# Max Rate: 126
# Mean Rate: 112.47888888888889
# Max Age: 580
# Mean Age: 145.60111111111112
# NOT: 618
# NAND: 0
# AND: 0
# OR_N: 0
# OR: 0
# AND_N: 0
# NOR: 0
# XOR: 0
# EQU: 0
#
#
# UPDATE: 666
# Min Length: (56, (15, 25))
# Max Length: (64, (14, 2))
# Mean Length: 60.233333333333334
# Min Rate: 57
# Max Rate: 128
# Mean Rate: 113.04222222222222
# Max Age: 412
# Mean Age: 144.2488888888889
# NOT: 631
# NAND: 0
# AND: 0
# OR_N: 0
# OR: 0
# AND_N: 0
# NOR: 0
# XOR: 0
# EQU: 0
#
#
# UPDATE: 672
# Min Length: (54, (14, 29))
# Max Length: (64, (13, 10))
# Mean Length: 60.26777777777778
# Min Rate: 57
# Max Rate: 128
# Mean Rate: 113.11222222222223
# Max Age: 448
# Mean Age: 143.2788888888889
# NOT: 637
# NAND: 0
# AND: 0
# OR_N: 0
# OR: 0
# AND_N: 0
# NOR: 0
# XOR: 0
# EQU: 0
#
#
# UPDATE: 678
# Min Length: (54, (14, 28))
# Max Length: (63, (13, 20))
# Mean Length: 60.27777777777778
# Min Rate: 57
# Max Rate: 126
# Mean Rate: 114.45777777777778
# Max Age: 560
# Mean Age: 143.79888888888888
# NOT: 659
# NAND: 0
# AND: 0
# OR_N: 0
# OR: 0
# AND_N: 0
# NOR: 0
# XOR: 0
# EQU: 0
#
#
# UPDATE: 684
# Min Length: (56, (18, 8))
# Max Length: (63, (12, 9))
# Mean Length: 60.28333333333333
# Min Rate: 57
# Max Rate: 126
# Mean Rate: 113.47777777777777
# Max Age: 704
# Mean Age: 142.5222222222222
# NOT: 644
# NAND: 0
# AND: 0
# OR_N: 0
# OR: 0
# AND_N: 0
# NOR: 0
# XOR: 0
# EQU: 0
#
#
# UPDATE: 690
# Min Length: (56, (23, 18))
# Max Length: (63, (11, 16))
# Mean Length: 60.31777777777778
# Min Rate: 57
# Max Rate: 126
# Mean Rate: 112.87444444444445
# Max Age: 476
# Mean Age: 149.13
# NOT: 636
# NAND: 0
# AND: 0
# OR_N: 0
# OR: 0
# AND_N: 0
# NOR: 0
# XOR: 0
# EQU: 0
#
#
# UPDATE: 696
# Min Length: (56, (18, 16))
# Max Length: (63, (7, 11))
# Mean Length: 60.306666666666665
# Min Rate: 57
# Max Rate: 126
# Mean Rate: 112.36777777777777
# Max Age: 468
# Mean Age: 151.10888888888888
# NOT: 629
# NAND: 0
# AND: 0
# OR_N: 0
# OR: 0
# AND_N: 0
# NOR: 0
# XOR: 0
# EQU: 0
#
#
# UPDATE: 702
# Min Length: (55, (29, 7))
# Max Length: (63, (0, 20))
# Mean Length: 60.34
# Min Rate: 57
# Max Rate: 126
# Mean Rate: 112.69222222222223
# Max Age: 454
# Mean Age: 143.5811111111111
# NOT: 618
# NAND: 0
# AND: 0
# OR_N: 0
# OR: 0
# AND_N: 0
# NOR: 0
# XOR: 0
# EQU: 0
#
#
# UPDATE: 708
# Min Length: (55, (26, 8))
# Max Length: (63, (8, 10))
# Mean Length: 60.327777777777776
# Min Rate: 57
# Max Rate: 126
# Mean Rate: 113.20333333333333
# Max Age: 520
# Mean Age: 144.4788888888889
# NOT: 645
# NAND: 0
# AND: 0
# OR_N: 0
# OR: 0
# AND_N: 0
# NOR: 0
# XOR: 0
# EQU: 0
#
#
# UPDATE: 714
# Min Length: (55, (25, 6))
# Max Length: (64, (20, 1))
# Mean Length: 60.30888888888889
# Min Rate: 56
# Max Rate: 128
# Mean Rate: 112.77555555555556
# Max Age: 498
# Mean Age: 135.20111111111112
# NOT: 624
# NAND: 0
# AND: 0
# OR_N: 0
# OR: 0
# AND_N: 0
# NOR: 0
# XOR: 0
# EQU: 0
#
#
# UPDATE: 720
# Min Length: (56, (11, 3))
# Max Length: (64, (20, 2))
# Mean Length: 60.355555555555554
# Min Rate: 56
# Max Rate: 128
# Mean Rate: 112.93111111111111
# Max Age: 466
# Mean Age: 137.40222222222224
# NOT: 639
# NAND: 0
# AND: 0
# OR_N: 0
# OR: 0
# AND_N: 0
# NOR: 0
# XOR: 0
# EQU: 0
#
#
# UPDATE: 726
# Min Length: (56, (12, 4))
# Max Length: (64, (18, 9))
# Mean Length: 60.39222222222222
# Min Rate: 58
# Max Rate: 128
# Mean Rate: 113.54222222222222
# Max Age: 472
# Mean Age: 149.04333333333332
# NOT: 668
# NAND: 0
# AND: 0
# OR_N: 0
# OR: 0
# AND_N: 0
# NOR: 0
# XOR: 0
# EQU: 0
#
#
# UPDATE: 732
# Min Length: (56, (12, 5))
# Max Length: (64, (21, 3))
# Mean Length: 60.39888888888889
# Min Rate: 58
# Max Rate: 128
# Mean Rate: 113.0988888888889
# Max Age: 432
# Mean Age: 138.5888888888889
# NOT: 630
# NAND: 1
# AND: 0
# OR_N: 0
# OR: 0
# AND_N: 0
# NOR: 0
# XOR: 0
# EQU: 0
#
#
# UPDATE: 738
# Min Length: (57, (6, 12))
# Max Length: (64, (22, 8))
# Mean Length: 60.422222222222224
# Min Rate: 58
# Max Rate: 128
# Mean Rate: 114.20555555555555
# Max Age: 406
# Mean Age: 139.68555555555557
# NOT: 665
# NAND: 2
# AND: 0
# OR_N: 0
# OR: 0
# AND_N: 0
# NOR: 0
# XOR: 0
# EQU: 0
#
#
# UPDATE: 744
# Min Length: (56, (3, 4))
# Max Length: (64, (16, 8))
# Mean Length: 60.434444444444445
# Min Rate: 58
# Max Rate: 128
# Mean Rate: 113.82111111111111
# Max Age: 446
# Mean Age: 135.45
# NOT: 628
# NAND: 2
# AND: 0
# OR_N: 0
# OR: 0
# AND_N: 0
# NOR: 0
# XOR: 0
# EQU: 0
#
#
# UPDATE: 750
# Min Length: (56, (24, 26))
# Max Length: (65, (23, 4))
# Mean Length: 60.44888888888889
# Min Rate: 58
# Max Rate: 130
# Mean Rate: 113.38111111111111
# Max Age: 466
# Mean Age: 132.99666666666667
# NOT: 631
# NAND: 5
# AND: 0
# OR_N: 0
# OR: 0
# AND_N: 0
# NOR: 0
# XOR: 0
# EQU: 0
#
#
# UPDATE: 756
# Min Length: (56, (24, 26))
# Max Length: (65, (17, 5))
# Mean Length: 60.43666666666667
# Min Rate: 57
# Max Rate: 130
# Mean Rate: 113.63555555555556
# Max Age: 444
# Mean Age: 139.3111111111111
# NOT: 636
# NAND: 4
# AND: 0
# OR_N: 0
# OR: 0
# AND_N: 0
# NOR: 0
# XOR: 0
# EQU: 0
# UPDATE: 762
# Min Length: (56, (29, 8))
# Max Length: (65, (24, 7))
# Mean Length: 60.467777777777776
# Min Rate: 56
# Max Rate: 130
# Mean Rate: 114.0111111111111
# Max Age: 410
# Mean Age: 138.05555555555554
# NOT: 618
# NAND: 4
# AND: 0
# OR_N: 0
# OR: 0
# AND_N: 0
# NOR: 0
# XOR: 0
# EQU: 0
#
#
# UPDATE: 768
# Min Length: (54, (29, 20))
# Max Length: (65, (26, 4))
# Mean Length: 60.50111111111111
# Min Rate: 56
# Max Rate: 130
# Mean Rate: 114.44222222222223
# Max Age: 360
# Mean Age: 139.43444444444444
# NOT: 662
# NAND: 3
# AND: 0
# OR_N: 0
# OR: 0
# AND_N: 0
# NOR: 0
# XOR: 0
# EQU: 0
#
#
# UPDATE: 774
# Min Length: (54, (29, 24))
# Max Length: (65, (26, 4))
# Mean Length: 60.556666666666665
# Min Rate: 57
# Max Rate: 130
# Mean Rate: 114.66333333333333
# Max Age: 470
# Mean Age: 133.72555555555556
# NOT: 618
# NAND: 3
# AND: 0
# OR_N: 0
# OR: 0
# AND_N: 0
# NOR: 0
# XOR: 0
# EQU: 0
#
#
# UPDATE: 780
# Min Length: (53, (27, 27))
# Max Length: (65, (28, 2))
# Mean Length: 60.57888888888889
# Min Rate: 58
# Max Rate: 130
# Mean Rate: 113.01222222222222
# Max Age: 430
# Mean Age: 134.34666666666666
# NOT: 640
# NAND: 5
# AND: 0
# OR_N: 0
# OR: 0
# AND_N: 0
# NOR: 0
# XOR: 0
# EQU: 0
#
#
# UPDATE: 786
# Min Length: (56, (20, 2))
# Max Length: (65, (28, 3))
# Mean Length: 60.57222222222222
# Min Rate: 58
# Max Rate: 130
# Mean Rate: 113.79777777777778
# Max Age: 444
# Mean Age: 134.28555555555556
# NOT: 639
# NAND: 6
# AND: 0
# OR_N: 0
# OR: 0
# AND_N: 0
# NOR: 0
# XOR: 0
# EQU: 0
#
#
# UPDATE: 792
# Min Length: (57, (5, 26))
# Max Length: (65, (28, 1))
# Mean Length: 60.583333333333336
# Min Rate: 58
# Max Rate: 130
# Mean Rate: 113.47666666666667
# Max Age: 438
# Mean Age: 134.76777777777778
# NOT: 636
# NAND: 3
# AND: 0
# OR_N: 0
# OR: 0
# AND_N: 0
# NOR: 0
# XOR: 0
# EQU: 0
#
#
# Reacting on nor
# Notifying experiment of function_IO
# Notifying experiment of function_IO
# Reacting on IO
# 1562314547 540380793 2732652748
# Notifying experiment of function_IO
# Notifying experiment of function_IO
# Reacting on IO
# 1837995527 1382777921 2456971768
# Notifying experiment of function_IO
# Notifying experiment of function_IO
# Reacting on IO
# 2677484427 867029539 1617482868
# Notifying experiment of function_IO
# Notifying experiment of function_IO
# Reacting on IO
# 2918639158 53920710 1376328137
# Notifying experiment of function_IO
# Notifying experiment of function_IO
# Reacting on IO
# 1156412741 2057277323 3138554554
# Notifying experiment of function_IO
# Notifying experiment of function_IO
# Reacting on IO
# 3827640203 2620695540 467327092
# Notifying experiment of function_IO
# Notifying experiment of function_IO
# Reacting on IO
# 1091105555 3224764198 3203861740
# Notifying experiment of function_IO
# Notifying experiment of function_IO
# Reacting on IO
# 3120618724 2650208351 1174348571
# Notifying experiment of function_IO
# Notifying experiment of function_IO
# Reacting on IO
# 236738948 3773611352 4058228347
# Notifying experiment of function_IO
# Notifying experiment of function_IO
# Reacting on IO
# 1506307057 3368483200 2788660238
# Reacting on nor
# Notifying experiment of function_IO
# Notifying experiment of function_IO
# Reacting on IO
# 1213899129 808246014 3081068166
# Notifying experiment of function_IO
# Notifying experiment of function_IO
# Reacting on IO
# 1220396446 3301853765 3074570849
# Notifying experiment of function_IO
# Notifying experiment of function_IO
# Reacting on IO
# 406191859 2034060243 3888775436
# Notifying experiment of function_IO
# Notifying experiment of function_IO
# Reacting on IO
# 553057058 2987783040 3741910237
# Notifying experiment of function_IO
# Notifying experiment of function_IO
# Reacting on IO
# 1004219875 2762296245 3290747420
# Notifying experiment of function_IO
# Notifying experiment of function_IO
# Reacting on IO
# 3119954971 1395094277 1175012324
# Notifying experiment of function_IO
# Notifying experiment of function_IO
# Reacting on IO
# 3088293177 2655484050 1206674118
# Notifying experiment of function_IO
# Notifying experiment of function_IO
# Reacting on IO
# 3406799449 3582247784 888167846
# Notifying experiment of function_IO
# Notifying experiment of function_IO
# Reacting on IO
# 3324475773 4193796017 970491522
# Notifying experiment of function_IO
# Notifying experiment of function_IO
# Reacting on IO
# 2906097760 1316531901 1388869535
# UPDATE: 798
# Min Length: (57, (2, 29))
# Max Length: (65, (28, 0))
# Mean Length: 60.54333333333334
# Min Rate: 58
# Max Rate: 1888
# Mean Rate: 118.62333333333333
# Max Age: 432
# Mean Age: 137.2722222222222
# NOT: 655
# NAND: 1
# AND: 0
# OR_N: 0
# OR: 0
# AND_N: 0
# NOR: 2
# XOR: 0
# EQU: 0
#
#
# UPDATE: 804
# Min Length: (57, (4, 29))
# Max Length: (65, (27, 0))
# Mean Length: 60.45484949832776
# Min Rate: 0
# Max Rate: 130
# Mean Rate: 114.85666666666667
# Max Age: 462
# Mean Age: 125.07555555555555
# NOT: 658
# NAND: 0
# AND: 0
# OR_N: 0
# OR: 0
# AND_N: 0
# NOR: 0
# XOR: 0
# EQU: 0
#
#
# UPDATE: 810
# Min Length: (57, (4, 24))
# Max Length: (66, (26, 0))
# Mean Length: 60.46666666666667
# Min Rate: 58
# Max Rate: 132
# Mean Rate: 115.1288888888889
# Max Age: 402
# Mean Age: 129.17111111111112
# NOT: 657
# NAND: 0
# AND: 0
# OR_N: 0
# OR: 0
# AND_N: 0
# NOR: 0
# XOR: 0
# EQU: 0
#
#
# UPDATE: 816
# Min Length: (57, (1, 23))
# Max Length: (65, (13, 18))
# Mean Length: 60.47222222222222
# Min Rate: 57
# Max Rate: 130
# Mean Rate: 113.88444444444444
# Max Age: 462
# Mean Age: 130.57
# NOT: 651
# NAND: 0
# AND: 0
# OR_N: 0
# OR: 0
# AND_N: 0
# NOR: 0
# XOR: 0
# EQU: 0
#
#
# UPDATE: 822
# Min Length: (57, (2, 24))
# Max Length: (65, (11, 19))
# Mean Length: 60.455555555555556
# Min Rate: 58
# Max Rate: 130
# Mean Rate: 114.87
# Max Age: 380
# Mean Age: 130.24444444444444
# NOT: 657
# NAND: 0
# AND: 0
# OR_N: 0
# OR: 0
# AND_N: 0
# NOR: 0
# XOR: 0
# EQU: 0
#
#
# UPDATE: 828
# Min Length: (56, (24, 16))
# Max Length: (65, (9, 22))
# Mean Length: 60.39
# Min Rate: 56
# Max Rate: 130
# Mean Rate: 115.10555555555555
# Max Age: 404
# Mean Age: 127.61111111111111
# NOT: 657
# NAND: 0
# AND: 0
# OR_N: 0
# OR: 0
# AND_N: 0
# NOR: 0
# XOR: 0
# EQU: 0
#
#
# UPDATE: 834
# Min Length: (56, (25, 18))
# Max Length: (65, (11, 22))
# Mean Length: 60.467777777777776
# Min Rate: 56
# Max Rate: 130
# Mean Rate: 116.09777777777778
# Max Age: 386
# Mean Age: 134.11333333333334
# NOT: 693
# NAND: 0
# AND: 0
# OR_N: 0
# OR: 0
# AND_N: 0
# NOR: 0
# XOR: 0
# EQU: 0
#
#
# UPDATE: 840
# Min Length: (57, (5, 21))
# Max Length: (65, (12, 23))
# Mean Length: 60.47222222222222
# Min Rate: 57
# Max Rate: 130
# Mean Rate: 115.37
# Max Age: 390
# Mean Age: 134.2111111111111
# NOT: 658
# NAND: 0
# AND: 0
# OR_N: 0
# OR: 0
# AND_N: 0
# NOR: 0
# XOR: 0
# EQU: 0
#
#
# UPDATE: 846
# Min Length: (56, (29, 8))
# Max Length: (65, (16, 28))
# Mean Length: 60.52777777777778
# Min Rate: 58
# Max Rate: 130
# Mean Rate: 114.86
# Max Age: 366
# Mean Age: 131.99444444444444
# NOT: 640
# NAND: 0
# AND: 0
# OR_N: 0
# OR: 0
# AND_N: 0
# NOR: 0
# XOR: 0
# EQU: 0
#
#
# UPDATE: 852
# Min Length: (56, (29, 5))
# Max Length: (65, (24, 21))
# Mean Length: 60.48777777777778
# Min Rate: 58
# Max Rate: 130
# Mean Rate: 114.16666666666667
# Max Age: 394
# Mean Age: 123.13
# NOT: 616
# NAND: 0
# AND: 0
# OR_N: 0
# OR: 0
# AND_N: 0
# NOR: 0
# XOR: 0
# EQU: 0
#
#
# UPDATE: 858
# Min Length: (56, (28, 6))
# Max Length: (65, (26, 20))
# Mean Length: 60.48555555555556
# Min Rate: 58
# Max Rate: 128
# Mean Rate: 114.58666666666667
# Max Age: 422
# Mean Age: 139.42
# NOT: 688
# NAND: 0
# AND: 0
# OR_N: 0
# OR: 0
# AND_N: 0
# NOR: 0
# XOR: 0
# EQU: 0
#
#
# UPDATE: 864
# Min Length: (56, (27, 5))
# Max Length: (65, (27, 19))
# Mean Length: 60.44111111111111
# Min Rate: 58
# Max Rate: 128
# Mean Rate: 115.17888888888889
# Max Age: 440
# Mean Age: 136.78222222222223
# NOT: 664
# NAND: 0
# AND: 0
# OR_N: 0
# OR: 0
# AND_N: 0
# NOR: 0
# XOR: 0
# EQU: 0
#
#
# UPDATE: 870
# Min Length: (56, (12, 29))
# Max Length: (65, (2, 11))
# Mean Length: 60.47555555555556
# Min Rate: 58
# Max Rate: 130
# Mean Rate: 115.45111111111112
# Max Age: 464
# Mean Age: 133.9088888888889
# NOT: 667
# NAND: 0
# AND: 0
# OR_N: 0
# OR: 0
# AND_N: 0
# NOR: 0
# XOR: 0
# EQU: 0
#
#
# UPDATE: 876
# Min Length: (56, (4, 29))
# Max Length: (65, (0, 27))
# Mean Length: 60.47888888888889
# Min Rate: 56
# Max Rate: 130
# Mean Rate: 115.40777777777778
# Max Age: 442
# Mean Age: 126.56777777777778
# NOT: 653
# NAND: 0
# AND: 0
# OR_N: 0
# OR: 0
# AND_N: 0
# NOR: 0
# XOR: 0
# EQU: 0
#
#
# UPDATE: 882
# Min Length: (56, (1, 25))
# Max Length: (65, (0, 27))
# Mean Length: 60.54888888888889
# Min Rate: 56
# Max Rate: 130
# Mean Rate: 114.92555555555556
# Max Age: 412
# Mean Age: 131.1211111111111
# NOT: 675
# NAND: 0
# AND: 0
# OR_N: 0
# OR: 0
# AND_N: 0
# NOR: 0
# XOR: 0
# EQU: 0
#
#
# UPDATE: 888
# Min Length: (56, (1, 6))
# Max Length: (65, (2, 11))
# Mean Length: 60.60444444444445
# Min Rate: 56
# Max Rate: 130
# Mean Rate: 114.82444444444444
# Max Age: 440
# Mean Age: 132.20555555555555
# NOT: 653
# NAND: 0
# AND: 0
# OR_N: 0
# OR: 0
# AND_N: 0
# NOR: 0
# XOR: 0
# EQU: 0
#
#
# UPDATE: 894
# Min Length: (56, (2, 5))
# Max Length: (66, (0, 11))
# Mean Length: 60.666666666666664
# Min Rate: 56
# Max Rate: 132
# Mean Rate: 114.39
# Max Age: 418
# Mean Age: 132.82444444444445
# NOT: 639
# NAND: 0
# AND: 0
# OR_N: 0
# OR: 0
# AND_N: 0
# NOR: 0
# XOR: 0
# EQU: 0
# UPDATE: 900
# Min Length: (56, (21, 18))
# Max Length: (66, (0, 12))
# Mean Length: 60.7
# Min Rate: 56
# Max Rate: 132
# Mean Rate: 114.38222222222223
# Max Age: 396
# Mean Age: 131.86777777777777
# NOT: 644
# NAND: 0
# AND: 0
# OR_N: 0
# OR: 0
# AND_N: 0
# NOR: 0
# XOR: 0
# EQU: 0
#
#
# UPDATE: 906
# Min Length: (56, (21, 18))
# Max Length: (66, (0, 11))
# Mean Length: 60.72666666666667
# Min Rate: 56
# Max Rate: 132
# Mean Rate: 114.65444444444445
# Max Age: 398
# Mean Age: 129.28444444444443
# NOT: 629
# NAND: 0
# AND: 0
# OR_N: 0
# OR: 0
# AND_N: 0
# NOR: 0
# XOR: 0
# EQU: 0
#
#
# UPDATE: 912
# Min Length: (56, (20, 11))
# Max Length: (67, (1, 11))
# Mean Length: 60.68888888888889
# Min Rate: 56
# Max Rate: 134
# Mean Rate: 114.70222222222222
# Max Age: 396
# Mean Age: 128.76777777777778
# NOT: 639
# NAND: 0
# AND: 0
# OR_N: 0
# OR: 0
# AND_N: 0
# NOR: 0
# XOR: 0
# EQU: 0
#
#
# UPDATE: 918
# Min Length: (56, (23, 13))
# Max Length: (65, (0, 13))
# Mean Length: 60.70777777777778
# Min Rate: 56
# Max Rate: 130
# Mean Rate: 114.60555555555555
# Max Age: 404
# Mean Age: 131.5888888888889
# NOT: 641
# NAND: 0
# AND: 0
# OR_N: 0
# OR: 0
# AND_N: 0
# NOR: 0
# XOR: 0
# EQU: 0
#
#
# Reacting on nor
# Notifying experiment of function_IO
# Notifying experiment of function_IO
# Reacting on IO
# 819940392 3090745451 3475026903
# Notifying experiment of function_IO
# Notifying experiment of function_IO
# Reacting on IO
# 3270286703 3386072886 1024680592
# Notifying experiment of function_IO
# Notifying experiment of function_IO
# Reacting on IO
# 1733930669 827991300 2561036626
# Notifying experiment of function_IO
# Notifying experiment of function_IO
# Reacting on IO
# 3958618882 1903353194 336348413
# Notifying experiment of function_IO
# Notifying experiment of function_IO
# Reacting on IO
# 1404740698 3213968828 2890226597
# Notifying experiment of function_IO
# Notifying experiment of function_IO
# Reacting on IO
# 3457646145 1735532859 837321150
# Notifying experiment of function_IO
# Notifying experiment of function_IO
# Reacting on IO
# 1540427051 3218360437 2754540244
# Notifying experiment of function_IO
# Notifying experiment of function_IO
# Reacting on IO
# 1819731013 1090123284 2475236282
# Notifying experiment of function_IO
# Notifying experiment of function_IO
# Reacting on IO
# 1998324217 36610471 2296643078
# Notifying experiment of function_IO
# Notifying experiment of function_IO
# Reacting on IO
# 821952870 889851120 3473014425
# UPDATE: 924
# Min Length: (56, (21, 13))
# Max Length: (66, (0, 17))
# Mean Length: 60.72666666666667
# Min Rate: 57
# Max Rate: 132
# Mean Rate: 114.63444444444444
# Max Age: 384
# Mean Age: 129.71666666666667
# NOT: 637
# NAND: 0
# AND: 0
# OR_N: 0
# OR: 0
# AND_N: 0
# NOR: 0
# XOR: 0
# EQU: 0
#
#
# UPDATE: 930
# Min Length: (56, (29, 26))
# Max Length: (66, (0, 19))
# Mean Length: 60.82
# Min Rate: 58
# Max Rate: 132
# Mean Rate: 115.22666666666667
# Max Age: 416
# Mean Age: 133.98222222222222
# NOT: 655
# NAND: 0
# AND: 0
# OR_N: 0
# OR: 0
# AND_N: 0
# NOR: 0
# XOR: 0
# EQU: 0
#
#
# UPDATE: 936
# Min Length: (56, (29, 28))
# Max Length: (66, (2, 20))
# Mean Length: 60.86222222222222
# Min Rate: 58
# Max Rate: 132
# Mean Rate: 115.71777777777778
# Max Age: 382
# Mean Age: 130.99555555555557
# NOT: 655
# NAND: 0
# AND: 0
# OR_N: 0
# OR: 0
# AND_N: 0
# NOR: 0
# XOR: 0
# EQU: 0
#
#
# UPDATE: 942
# Min Length: (56, (7, 25))
# Max Length: (66, (2, 18))
# Mean Length: 60.89666666666667
# Min Rate: 59
# Max Rate: 132
# Mean Rate: 115.71111111111111
# Max Age: 446
# Mean Age: 129.84333333333333
# NOT: 680
# NAND: 0
# AND: 0
# OR_N: 0
# OR: 0
# AND_N: 0
# NOR: 0
# XOR: 0
# EQU: 0
#
#
# UPDATE: 948
# Min Length: (56, (9, 25))
# Max Length: (66, (2, 22))
# Mean Length: 60.943333333333335
# Min Rate: 57
# Max Rate: 132
# Mean Rate: 116.24555555555555
# Max Age: 422
# Mean Age: 137.55777777777777
# NOT: 698
# NAND: 0
# AND: 0
# OR_N: 0
# OR: 0
# AND_N: 0
# NOR: 0
# XOR: 0
# EQU: 0
#
#
# UPDATE: 954
# Min Length: (55, (0, 28))
# Max Length: (65, (0, 19))
# Mean Length: 60.88111111111111
# Min Rate: 57
# Max Rate: 130
# Mean Rate: 116.49888888888889
# Max Age: 420
# Mean Age: 132.16
# NOT: 691
# NAND: 0
# AND: 0
# OR_N: 0
# OR: 0
# AND_N: 0
# NOR: 0
# XOR: 0
# EQU: 0
#
#
# UPDATE: 960
# Min Length: (55, (1, 27))
# Max Length: (65, (0, 14))
# Mean Length: 60.92
# Min Rate: 57
# Max Rate: 130
# Mean Rate: 116.54777777777778
# Max Age: 428
# Mean Age: 134.82444444444445
# NOT: 679
# NAND: 0
# AND: 0
# OR_N: 0
# OR: 0
# AND_N: 0
# NOR: 0
# XOR: 0
# EQU: 0
#
#
# UPDATE: 966
# Min Length: (57, (5, 22))
# Max Length: (65, (0, 19))
# Mean Length: 60.973333333333336
# Min Rate: 58
# Max Rate: 130
# Mean Rate: 116.01555555555555
# Max Age: 414
# Mean Age: 130.23444444444445
# NOT: 665
# NAND: 0
# AND: 1
# OR_N: 0
# OR: 0
# AND_N: 0
# NOR: 0
# XOR: 0
# EQU: 0
#
#
# UPDATE: 972
# Min Length: (56, (18, 8))
# Max Length: (65, (0, 25))
# Mean Length: 61.004444444444445
# Min Rate: 57
# Max Rate: 130
# Mean Rate: 116.48
# Max Age: 386
# Mean Age: 128.20666666666668
# NOT: 659
# NAND: 0
# AND: 0
# OR_N: 0
# OR: 0
# AND_N: 0
# NOR: 0
# XOR: 0
# EQU: 0
#
#
# UPDATE: 978
# Min Length: (56, (18, 8))
# Max Length: (65, (1, 11))
# Mean Length: 61.01
# Min Rate: 57
# Max Rate: 130
# Mean Rate: 117.04666666666667
# Max Age: 468
# Mean Age: 130.26111111111112
# NOT: 703
# NAND: 0
# AND: 0
# OR_N: 0
# OR: 0
# AND_N: 0
# NOR: 0
# XOR: 0
# EQU: 0
#
#
# UPDATE: 984
# Min Length: (56, (16, 9))
# Max Length: (65, (0, 11))
# Mean Length: 60.99666666666667
# Min Rate: 57
# Max Rate: 130
# Mean Rate: 117.47777777777777
# Max Age: 370
# Mean Age: 134.79222222222222
# NOT: 695
# NAND: 1
# AND: 0
# OR_N: 0
# OR: 0
# AND_N: 0
# NOR: 0
# XOR: 0
# EQU: 0
#
#
# UPDATE: 990
# Min Length: (56, (6, 28))
# Max Length: (66, (7, 10))
# Mean Length: 60.99888888888889
# Min Rate: 58
# Max Rate: 236
# Mean Rate: 118.27111111111111
# Max Age: 430
# Mean Age: 125.01333333333334
# NOT: 660
# NAND: 4
# AND: 0
# OR_N: 0
# OR: 0
# AND_N: 0
# NOR: 0
# XOR: 0
# EQU: 0
#
#
# UPDATE: 996
# Min Length: (56, (7, 28))
# Max Length: (65, (0, 18))
# Mean Length: 60.99666666666667
# Min Rate: 58
# Max Rate: 240
# Mean Rate: 120.27555555555556
# Max Age: 496
# Mean Age: 131.67222222222222
# NOT: 722
# NAND: 16
# AND: 0
# OR_N: 0
# OR: 0
# AND_N: 0
# NOR: 0
# XOR: 0
# EQU: 0
#
#
# UPDATE: 1002
# Min Length: (55, (7, 28))
# Max Length: (65, (0, 16))
# Mean Length: 60.98888888888889
# Min Rate: 58
# Max Rate: 240
# Mean Rate: 123.05
# Max Age: 398
# Mean Age: 128.0988888888889
# NOT: 698
# NAND: 44
# AND: 0
# OR_N: 0
# OR: 0
# AND_N: 0
# NOR: 0
# XOR: 0
# EQU: 0
#
#
# UPDATE: 1008
# Min Length: (53, (8, 28))
# Max Length: (66, (14, 21))
# Mean Length: 60.82
# Min Rate: 57
# Max Rate: 252
# Mean Rate: 130.01888888888888
# Max Age: 424
# Mean Age: 125.88777777777777
# NOT: 660
# NAND: 58
# AND: 0
# OR_N: 0
# OR: 0
# AND_N: 0
# NOR: 0
# XOR: 0
# EQU: 0
#
#
# UPDATE: 1014
# Min Length: (53, (8, 26))
# Max Length: (66, (12, 18))
# Mean Length: 60.666666666666664
# Min Rate: 58
# Max Rate: 472
# ...
# Mean Length: 74.11
# Min Rate: 68
# Max Rate: 4928
# Mean Rate: 1037.4944444444445
# Max Age: 1062
# Mean Age: 127.80888888888889
# NOT: 623
# NAND: 0
# AND: 1
# OR_N: 27
# OR: 529
# AND_N: 0
# NOR: 0
# XOR: 0
# EQU: 0
#
#
# UPDATE: 2814
# Min Length: (67, (19, 20))
# Max Length: (80, (11, 21))
# Mean Length: 74.13
# Min Rate: 68
# Max Rate: 4928
# Mean Rate: 1016.3177777777778
# Max Age: 1120
# Mean Age: 131.6822222222222
# NOT: 638
# NAND: 0
# AND: 0
# OR_N: 35
# OR: 538
# AND_N: 0
# NOR: 0
# XOR: 0
# EQU: 0
#
#
# UPDATE: 2820
# Min Length: (68, (13, 4))
# Max Length: (80, (9, 25))
# Mean Length: 74.14444444444445
# Min Rate: 70
# Max Rate: 4928
# Mean Rate: 1040.3211111111111
# Max Age: 648
# Mean Age: 135.8388888888889
# NOT: 641
# NAND: 0
# AND: 0
# OR_N: 29
# OR: 546
# AND_N: 0
# NOR: 0
# XOR: 0
# EQU: 0
#
#
# UPDATE: 2826
# Min Length: (67, (9, 12))
# Max Length: (80, (9, 27))
# Mean Length: 74.1588888888889
# Min Rate: 70
# Max Rate: 4928
# Mean Rate: 1043.2566666666667
# Max Age: 828
# Mean Age: 139.61111111111111
# NOT: 651
# NAND: 1
# AND: 0
# OR_N: 30
# OR: 571
# AND_N: 0
# NOR: 0
# XOR: 0
# EQU: 0
#
#
# UPDATE: 2832
# Min Length: (69, (21, 4))
# Max Length: (80, (3, 13))
# Mean Length: 74.19555555555556
# Min Rate: 70
# Max Rate: 4736
# Mean Rate: 1040.8822222222223
# Max Age: 578
# Mean Age: 132.9011111111111
# NOT: 656
# NAND: 0
# AND: 0
# OR_N: 28
# OR: 543
# AND_N: 1
# NOR: 0
# XOR: 0
# EQU: 0
#
#
# Reacting on nor
# Notifying experiment of function_IO
# Notifying experiment of function_IO
# Reacting on IO
# 2456041198 3075519362 3077879790
# Notifying experiment of function_IO
# Notifying experiment of function_IO
# Reacting on IO
# 1346522329 772626474 2119130363
# Notifying experiment of function_IO
# Notifying experiment of function_IO
# Reacting on IO
# 1034800829 554216228 1034809277
# Notifying experiment of function_IO
# Notifying experiment of function_IO
# Reacting on IO
# 2224891994 1827487313 3976019547
# Notifying experiment of function_IO
# Notifying experiment of function_IO
# Reacting on IO
# 1934887125 308855854 1937558783
# Notifying experiment of function_IO
# Notifying experiment of function_IO
# Reacting on IO
# 1693865922 228832326 1844967366
# Notifying experiment of function_IO
# Notifying experiment of function_IO
# Reacting on IO
# 4211342268 2763256345 4289985469
# Notifying experiment of function_IO
# Notifying experiment of function_IO
# Reacting on IO
# 3084676206 747382426 3218894590
# Notifying experiment of function_IO
# Notifying experiment of function_IO
# Reacting on IO
# 3132210557 1478282837 4206755709
# Notifying experiment of function_IO
# Notifying experiment of function_IO
# Reacting on IO
# 1882162983 2977117149 4051679231
# Reacting on nor
# Notifying experiment of function_IO
# Notifying experiment of function_IO
# Reacting on IO
# 83870122 3252179730 3321877434
# Notifying experiment of function_IO
# Notifying experiment of function_IO
# Reacting on IO
# 1124089516 1013178640 2137259964
# Notifying experiment of function_IO
# Notifying experiment of function_IO
# Reacting on IO
# 950359360 2429864716 3103121228
# Notifying experiment of function_IO
# Notifying experiment of function_IO
# Reacting on IO
# 4245592128 338445129 4247706441
# Notifying experiment of function_IO
# Notifying experiment of function_IO
# Reacting on IO
# 1603261910 1333273035 1610610143
# Notifying experiment of function_IO
# Notifying experiment of function_IO
# Reacting on IO
# 4105571319 3805866346 4143901695
# Notifying experiment of function_IO
# Notifying experiment of function_IO
# Reacting on IO
# 1490878531 1904287596 2044534639
# Notifying experiment of function_IO
# Notifying experiment of function_IO
# Reacting on IO
# 1139147716 117288788 1207939028
# Notifying experiment of function_IO
# Notifying experiment of function_IO
# Reacting on IO
# 2721931496 2299657544 2872966632
# Notifying experiment of function_IO
# Notifying experiment of function_IO
# Reacting on IO
# 1505133340 2806792180 4294885372
# UPDATE: 2838
# Min Length: (69, (19, 5))
# Max Length: (80, (5, 29))
# Mean Length: 74.21444444444444
# Min Rate: 71
# Max Rate: 19456
# Mean Rate: 1100.61
# Max Age: 752
# Mean Age: 136.71555555555557
# NOT: 652
# NAND: 0
# AND: 0
# OR_N: 37
# OR: 563
# AND_N: 0
# NOR: 2
# XOR: 0
# EQU: 0
#
#
# UPDATE: 2844
# Min Length: (68, (22, 15))
# Max Length: (80, (4, 16))
# Mean Length: 74.19222222222223
# Min Rate: 71
# Max Rate: 19456
# Mean Rate: 1139.131111111111
# Max Age: 1216
# Mean Age: 134.16444444444446
# NOT: 633
# NAND: 0
# AND: 0
# OR_N: 22
# OR: 546
# AND_N: 0
# NOR: 1
# XOR: 0
# EQU: 0
#
#
# UPDATE: 2850
# Min Length: (69, (7, 20))
# Max Length: (80, (2, 17))
# Mean Length: 74.19777777777777
# Min Rate: 71
# Max Rate: 19456
# Mean Rate: 1140.2544444444445
# Max Age: 1554
# Mean Age: 130.85333333333332
# NOT: 610
# NAND: 0
# AND: 0
# OR_N: 18
# OR: 535
# AND_N: 0
# NOR: 1
# XOR: 0
# EQU: 0
#
#
# UPDATE: 2856
# Min Length: (67, (11, 3))
# Max Length: (79, (0, 3))
# Mean Length: 74.23222222222222
# Min Rate: 71
# Max Rate: 19456
# Mean Rate: 1151.1733333333334
# Max Age: 2208
# Mean Age: 130.3711111111111
# NOT: 591
# NAND: 0
# AND: 0
# OR_N: 23
# OR: 519
# AND_N: 2
# NOR: 1
# XOR: 0
# EQU: 0
#
#
# UPDATE: 2862
# Min Length: (67, (13, 24))
# Max Length: (80, (27, 20))
# Mean Length: 74.30111111111111
# Min Rate: 71
# Max Rate: 19456
# Mean Rate: 1064.5877777777778
# Max Age: 2208
# Mean Age: 120.70777777777778
# NOT: 566
# NAND: 0
# AND: 0
# OR_N: 18
# OR: 480
# AND_N: 1
# NOR: 0
# XOR: 0
# EQU: 0
#
#
# UPDATE: 2868
# Min Length: (67, (26, 24))
# Max Length: (80, (4, 8))
# Mean Length: 74.24666666666667
# Min Rate: 71
# Max Rate: 19456
# Mean Rate: 1084.2055555555555
# Max Age: 2176
# Mean Age: 120.06666666666666
# NOT: 577
# NAND: 1
# AND: 1
# OR_N: 28
# OR: 479
# AND_N: 1
# NOR: 0
# XOR: 0
# EQU: 0
#
#
# UPDATE: 2874
# Min Length: (70, (11, 24))
# Max Length: (80, (0, 7))
# Mean Length: 74.972191323693
# Min Rate: 0
# Max Rate: 38400
# Mean Rate: 1109.83
# Max Age: 1757
# Mean Age: 113.64111111111112
# NOT: 534
# NAND: 0
# AND: 1
# OR_N: 26
# OR: 464
# AND_N: 1
# NOR: 0
# XOR: 0
# EQU: 0
#
#
# UPDATE: 2880
# Min Length: (70, (19, 13))
# Max Length: (80, (0, 7))
# Mean Length: 75.45333333333333
# Min Rate: 71
# Max Rate: 38400
# Mean Rate: 1021.2622222222222
# Max Age: 2400
# Mean Age: 102.55333333333333
# NOT: 501
# NAND: 0
# AND: 0
# OR_N: 28
# OR: 421
# AND_N: 0
# NOR: 0
# XOR: 0
# EQU: 0
#
#
# UPDATE: 2886
# Min Length: (70, (7, 17))
# Max Length: (80, (1, 2))
# Mean Length: 75.24888888888889
# Min Rate: 71
# Max Rate: 9728
# Mean Rate: 986.1177777777777
# Max Age: 1664
# Mean Age: 123.61555555555556
# NOT: 579
# NAND: 0
# AND: 0
# OR_N: 28
# OR: 498
# AND_N: 0
# NOR: 0
# XOR: 0
# EQU: 0
#
#
# UPDATE: 2892
# Min Length: (70, (8, 21))
# Max Length: (80, (1, 2))
# Mean Length: 75.28
# Min Rate: 71
# Max Rate: 9856
# Mean Rate: 1003.0622222222222
# Max Age: 2080
# Mean Age: 131.63888888888889
# NOT: 599
# NAND: 1
# AND: 2
# OR_N: 38
# OR: 500
# AND_N: 0
# NOR: 0
# XOR: 0
# EQU: 0
#
#
# UPDATE: 2898
# Min Length: (70, (4, 22))
# Max Length: (81, (27, 18))
# Mean Length: 75.28555555555556
# Min Rate: 71
# Max Rate: 1296
# Mean Rate: 975.3766666666667
# Max Age: 578
# Mean Age: 129.44333333333333
# NOT: 588
# NAND: 0
# AND: 1
# OR_N: 25
# OR: 501
# AND_N: 0
# NOR: 0
# XOR: 0
# EQU: 0
#
#
# UPDATE: 2904
# Min Length: (70, (5, 21))
# Max Length: (81, (26, 18))
# Mean Length: 75.27111111111111
# Min Rate: 70
# Max Rate: 9600
# Mean Rate: 1078.4733333333334
# Max Age: 546
# Mean Age: 144.9788888888889
# NOT: 667
# NAND: 0
# AND: 0
# OR_N: 19
# OR: 563
# AND_N: 1
# NOR: 0
# XOR: 0
# EQU: 0
#
#
# UPDATE: 2910
# Min Length: (70, (6, 22))
# Max Length: (80, (0, 2))
# Mean Length: 75.27
# Min Rate: 71
# Max Rate: 9856
# Mean Rate: 1087.2088888888889
# Max Age: 632
# Mean Age: 140.17777777777778
# NOT: 653
# NAND: 1
# AND: 0
# OR_N: 26
# OR: 560
# AND_N: 0
# NOR: 0
# XOR: 0
# EQU: 0
#
#
# UPDATE: 2916
# Min Length: (70, (7, 23))
# Max Length: (80, (1, 1))
# Mean Length: 75.41222222222223
# Min Rate: 71
# Max Rate: 9856
# Mean Rate: 1066.82
# Max Age: 1048
# Mean Age: 134.45222222222222
# NOT: 625
# NAND: 0
# AND: 1
# OR_N: 21
# OR: 542
# AND_N: 1
# NOR: 0
# XOR: 0
# EQU: 0
#
#
# UPDATE: 2922
# Min Length: (70, (5, 22))
# Max Length: (81, (21, 10))
# Mean Length: 75.56222222222222
# Min Rate: 72
# Max Rate: 9856
# Mean Rate: 1041.6544444444444
# Max Age: 1784
# Mean Age: 136.63
# NOT: 624
# NAND: 1
# AND: 0
# OR_N: 24
# OR: 533
# AND_N: 0
# NOR: 0
# XOR: 0
# EQU: 0
#
#
# UPDATE: 2928
# Min Length: (70, (1, 29))
# Max Length: (81, (19, 10))
# Mean Length: 75.45
# Min Rate: 72
# Max Rate: 9728
# Mean Rate: 1023.1755555555555
# Max Age: 584
# Mean Age: 128.35111111111112
# NOT: 610
# NAND: 0
# AND: 0
# OR_N: 27
# OR: 525
# AND_N: 0
# NOR: 0
# XOR: 0
# EQU: 0
#
#
# UPDATE: 2934
# Min Length: (70, (0, 23))
# Max Length: (81, (6, 0))
# Mean Length: 75.44888888888889
# Min Rate: 72
# Max Rate: 9856
# Mean Rate: 1026.4633333333334
# Max Age: 1184
# Mean Age: 130.79888888888888
# NOT: 608
# NAND: 1
# AND: 0
# OR_N: 19
# OR: 523
# AND_N: 0
# NOR: 0
# XOR: 0
# EQU: 0
# UPDATE: 2940
# Min Length: (70, (3, 20))
# Max Length: (81, (20, 3))
# Mean Length: 75.5411111111111
# Min Rate: 72
# Max Rate: 9856
# Mean Rate: 1038.4722222222222
# Max Age: 1664
# Mean Age: 133.22666666666666
# NOT: 593
# NAND: 2
# AND: 0
# OR_N: 22
# OR: 507
# AND_N: 0
# NOR: 0
# XOR: 0
# EQU: 0
#
#
# UPDATE: 2946
# Min Length: (69, (3, 25))
# Max Length: (81, (19, 12))
# Mean Length: 75.54888888888888
# Min Rate: 69
# Max Rate: 9600
# Mean Rate: 1023.1655555555556
# Max Age: 1112
# Mean Age: 125.84777777777778
# NOT: 609
# NAND: 2
# AND: 0
# OR_N: 23
# OR: 518
# AND_N: 0
# NOR: 0
# XOR: 0
# EQU: 0
#
#
# UPDATE: 2952
# Min Length: (70, (1, 17))
# Max Length: (81, (17, 6))
# Mean Length: 75.57333333333334
# Min Rate: 72
# Max Rate: 5760
# Mean Rate: 1002.5
# Max Age: 1040
# Mean Age: 131.69333333333333
# NOT: 587
# NAND: 1
# AND: 0
# OR_N: 26
# OR: 506
# AND_N: 0
# NOR: 0
# XOR: 0
# EQU: 0
#
#
# UPDATE: 2958
# Min Length: (70, (7, 17))
# Max Length: (81, (6, 23))
# Mean Length: 75.53666666666666
# Min Rate: 71
# Max Rate: 1296
# Mean Rate: 1005.8
# Max Age: 579
# Mean Age: 136.17333333333335
# NOT: 621
# NAND: 3
# AND: 0
# OR_N: 25
# OR: 527
# AND_N: 1
# NOR: 0
# XOR: 0
# EQU: 0
#
#
# UPDATE: 2964
# Min Length: (70, (7, 13))
# Max Length: (83, (5, 8))
# Mean Length: 75.54666666666667
# Min Rate: 71
# Max Rate: 10368
# Mean Rate: 1148.84
# Max Age: 982
# Mean Age: 138.51777777777778
# NOT: 647
# NAND: 3
# AND: 0
# OR_N: 25
# OR: 552
# AND_N: 2
# NOR: 0
# XOR: 0
# EQU: 0
#
#
# UPDATE: 2970
# Min Length: (70, (5, 13))
# Max Length: (86, (8, 2))
# Mean Length: 75.67111111111112
# Min Rate: 71
# Max Rate: 10368
# Mean Rate: 1217.808888888889
# Max Age: 1622
# Mean Age: 139.61111111111111
# NOT: 625
# NAND: 0
# AND: 0
# OR_N: 24
# OR: 532
# AND_N: 2
# NOR: 0
# XOR: 0
# EQU: 0
#
#
# UPDATE: 2976
# Min Length: (68, (3, 13))
# Max Length: (89, (10, 12))
# Mean Length: 75.73777777777778
# Min Rate: 72
# Max Rate: 10368
# Mean Rate: 1204.8633333333332
# Max Age: 1952
# Mean Age: 140.19555555555556
# NOT: 604
# NAND: 0
# AND: 0
# OR_N: 18
# OR: 528
# AND_N: 1
# NOR: 0
# XOR: 0
# EQU: 0
#
#
# UPDATE: 2982
# Min Length: (68, (7, 17))
# Max Length: (82, (2, 5))
# Mean Length: 75.89666666666666
# Min Rate: 72
# Max Rate: 10368
# Mean Rate: 1173.8477777777778
# Max Age: 2168
# Mean Age: 137.54111111111112
# NOT: 598
# NAND: 0
# AND: 1
# OR_N: 22
# OR: 530
# AND_N: 1
# NOR: 0
# XOR: 0
# EQU: 0
#
#
# UPDATE: 2988
# Min Length: (71, (2, 28))
# Max Length: (82, (1, 4))
# Mean Length: 76.08333333333333
# Min Rate: 72
# Max Rate: 10368
# Mean Rate: 1125.2377777777779
# Max Age: 2080
# Mean Age: 140.89222222222222
# NOT: 576
# NAND: 0
# AND: 0
# OR_N: 25
# OR: 511
# AND_N: 0
# NOR: 0
# XOR: 0
# EQU: 0
#
#
# UPDATE: 2994
# Min Length: (71, (13, 7))
# Max Length: (82, (3, 8))
# Mean Length: 76.16888888888889
# Min Rate: 73
# Max Rate: 10240
# Mean Rate: 1078.75
# Max Age: 1976
# Mean Age: 134.45666666666668
# NOT: 583
# NAND: 0
# AND: 1
# OR_N: 21
# OR: 507
# AND_N: 0
# NOR: 0
# XOR: 0
# EQU: 0
#
#
# UPDATE: 3000
# Min Length: (71, (17, 29))
# Max Length: (82, (2, 10))
# Mean Length: 76.29555555555555
# Min Rate: 72
# Max Rate: 4864
# Mean Rate: 998.1844444444445
# Max Age: 598
# Mean Age: 126.39111111111112
# NOT: 585
# NAND: 0
# AND: 0
# OR_N: 16
# OR: 498
# AND_N: 0
# NOR: 0
# XOR: 0
# EQU: 0
#
#
# UPDATE: 3006
# Min Length: (71, (27, 11))
# Max Length: (82, (3, 14))
# Mean Length: 76.28222222222222
# Min Rate: 73
# Max Rate: 9856
# Mean Rate: 1019.14
# Max Age: 888
# Mean Age: 131.19555555555556
# NOT: 594
# NAND: 1
# AND: 0
# OR_N: 22
# OR: 516
# AND_N: 1
# NOR: 0
# XOR: 0
# EQU: 0
#
#
# UPDATE: 3012
# Min Length: (68, (21, 23))
# Max Length: (81, (8, 16))
# Mean Length: 76.13333333333334
# Min Rate: 73
# Max Rate: 9856
# Mean Rate: 1029.5855555555556
# Max Age: 1592
# Mean Age: 132.7277777777778
# NOT: 597
# NAND: 1
# AND: 0
# OR_N: 13
# OR: 526
# AND_N: 1
# NOR: 0
# XOR: 0
# EQU: 0
#
#
# UPDATE: 3018
# Min Length: (68, (19, 25))
# Max Length: (81, (8, 21))
# Mean Length: 76.0411111111111
# Min Rate: 73
# Max Rate: 4864
# Mean Rate: 1025.6822222222222
# Max Age: 600
# Mean Age: 128.02444444444444
# NOT: 602
# NAND: 1
# AND: 0
# OR_N: 9
# OR: 532
# AND_N: 0
# NOR: 0
# XOR: 0
# EQU: 0
#
#
# UPDATE: 3024
# Min Length: (71, (13, 9))
# Max Length: (81, (10, 19))
# Mean Length: 75.96222222222222
# Min Rate: 73
# Max Rate: 5056
# Mean Rate: 1081.5566666666666
# Max Age: 555
# Mean Age: 136.61444444444444
# NOT: 614
# NAND: 10
# AND: 0
# OR_N: 22
# OR: 540
# AND_N: 0
# NOR: 0
# XOR: 0
# EQU: 0
#
#
# UPDATE: 3030
# Min Length: (71, (2, 11))
# Max Length: (81, (8, 14))
# Mean Length: 76.06555555555556
# Min Rate: 73
# Max Rate: 38400
# Mean Rate: 1263.6444444444444
# Max Age: 908
# Mean Age: 134.89555555555555
# NOT: 586
# NAND: 77
# AND: 1
# OR_N: 15
# OR: 534
# AND_N: 0
# NOR: 0
# XOR: 0
# EQU: 0
#
#
# UPDATE: 3036
# Min Length: (71, (10, 16))
# Max Length: (81, (9, 1))
# Mean Length: 75.82555555555555
# Min Rate: 73
# Max Rate: 38400
# Mean Rate: 1460.5711111111111
# Max Age: 1056
# Mean Age: 117.64777777777778
# NOT: 559
# NAND: 203
# AND: 0
# OR_N: 13
# OR: 479
# AND_N: 0
# NOR: 0
# XOR: 0
# EQU: 0
#
#
# UPDATE: 3042
# Min Length: (71, (12, 7))
# Max Length: (81, (10, 2))
# Mean Length: 75.52111111111111
# Min Rate: 73
# Max Rate: 38400
# Mean Rate: 1616.3422222222223
# Max Age: 1440
# Mean Age: 111.79888888888888
# NOT: 529
# NAND: 291
# AND: 0
# OR_N: 12
# OR: 439
# AND_N: 0
# NOR: 0
# XOR: 0
# EQU: 0
#
#
# Reacting on nor
# Notifying experiment of function_IO
# Notifying experiment of function_IO
# Reacting on IO
# 3628533355 2450322455 632293760
# Test passed
# Notifying experiment of function_IO
# Reacting on IO
# 996140139 3832818419 3298827156
# Notifying experiment of function_IO
# Reacting on IO
# 996140139 3832818419 3298827156
# Notifying experiment of function_IO
# Notifying experiment of function_IO
# Reacting on IO
# 1022582175 530068549 3221520928
# Test passed
# Notifying experiment of function_IO
# Reacting on IO
# 3509210337 1589561431 785756958
# Notifying experiment of function_IO
# Reacting on IO
# 3509210337 1589561431 785756958
# Notifying experiment of function_IO
# Notifying experiment of function_IO
# Reacting on IO
# 3953724575 4213916828 72659808
# Test passed
# Notifying experiment of function_IO
# Reacting on IO
# 3855476288 2188862666 439491007
# Notifying experiment of function_IO
# Reacting on IO
# 3855476288 2188862666 439491007
# Notifying experiment of function_IO
# Notifying experiment of function_IO
# Reacting on IO
# 982648410 3055642482 1095538821
# Test passed
# Notifying experiment of function_IO
# Reacting on IO
# 2463578298 2389997850 1831388997
# Notifying experiment of function_IO
# Reacting on IO
# 2463578298 2389997850 1831388997
# Notifying experiment of function_IO
# Notifying experiment of function_IO
# Reacting on IO
# 711367086 3256946747 362309184
# Test passed
# Notifying experiment of function_IO
# Reacting on IO
# 4228727109 2330105003 66240186
# Notifying experiment of function_IO
# Reacting on IO
# 4228727109 2330105003 66240186
# Notifying experiment of function_IO
# Notifying experiment of function_IO
# Reacting on IO
# 1315129278 3611208494 545263681
# Test passed
# Notifying experiment of function_IO
# Reacting on IO
# 2701044861 1607924710 1593922434
# Notifying experiment of function_IO
# Reacting on IO
# 2701044861 1607924710 1593922434
# Notifying experiment of function_IO
# Notifying experiment of function_IO
# Reacting on IO
# 510707959 1040428522 3247182336
# Test passed
# Notifying experiment of function_IO
# Reacting on IO
# 2563441461 21924465 1731525834
# Notifying experiment of function_IO
# Reacting on IO
# 2563441461 21924465 1731525834
# Notifying experiment of function_IO
# Notifying experiment of function_IO
# Reacting on IO
# 2625782609 4243169284 51649706
# Test passed
# Notifying experiment of function_IO
# Reacting on IO
# 2879012131 2837972569 1415955164
# Notifying experiment of function_IO
# Reacting on IO
# 2879012131 2837972569 1415955164
# Notifying experiment of function_IO
# Notifying experiment of function_IO
# Reacting on IO
# 291611285 1482457861 2793561194
# Test passed
# Notifying experiment of function_IO
# Reacting on IO
# 3649113953 2612105580 645853342
# Notifying experiment of function_IO
# Reacting on IO
# 3649113953 2612105580 645853342
# Notifying experiment of function_IO
# Notifying experiment of function_IO
# Reacting on IO
# 1520026143 1136538100 2755660800
# Test passed
# Notifying experiment of function_IO
# Reacting on IO
# 2475526886 3974159473 1819440409
# Notifying experiment of function_IO
# Reacting on IO
# 2475526886 3974159473 1819440409
# Wall time: 1h 40min 37s

# %% [markdown]
# Display Experiment Statistics and Update

# %%
print("Update: " + str(experiment.update))
experiment.display_statistics()
# Out:
# Update: 3047
# Min Length: (72, (5, 21))
# Max Length: (81, (12, 0))
# Mean Length: 75.21777777777778
# Min Rate: 72
# Max Rate: 38912
# Mean Rate: 1752.58
# Max Age: 1664
# Mean Age: 105.8
# NOT: 485
# NAND: 329
# AND: 0
# OR_N: 10
# OR: 413
# AND_N: 0
# NOR: 1
# XOR: 0
# EQU: 0

# %% [markdown]
# Test the Resulting Organism

# %%
"""
A script to test the evolved organism
"""

world = World(1,notify_ = True)
world.place_custom(em.original_memory)
world.schedule(1000)
# Out:
# EMULATOR AT POSITION (0, 0) COMPUTED NOT
# INPUT:  4091691660
# OUTPUT: 203275635
#
# EMULATOR AT POSITION (0, 0) COMPUTED NOR
# INPUT: [ 250556420 4091691660]
# OUTPUT:  1084787
#
# EMULATOR AT POSITION (0, 0) COMPUTED NOT
# INPUT:  2347630051
# OUTPUT: 1947337244
#
# EMULATOR AT POSITION (0, 0) COMPUTED NOT
# INPUT:  2347630051
# OUTPUT: 1947337244

# %% [markdown]
# Pull out statistics

# %%
print("Length of the organism: " + str(len(experiment.first_specimen)))

"""
A script to count the mutation types
"""

c = 0
ins = 0
d = 0

for i in range(len(em.mutations)):
    
    if em.mutations[i][0] == "C":
        c += 1
    elif em.mutations[i][0] == "I":
        ins += 1
    elif em.mutations[i][0] == "D":
        d += 1
        
print("Copy: " + str(c))
print("Insert: " + str(ins))
print("Delete: " + str(d))
print("TOTAL: " + str(c+d+ins))
# Out:
# Length of the organism: 73
# Copy: 115
# Insert: 22
# Delete: 19
# TOTAL: 156

# %%
print("Number of Generations: " + str(em.mutations[-1][-1]))
# Out:
# Number of Generations: 631

# %%
"""
A Script to recreate the program from the ancestor and the mutations
"""

start = em.ancestor.copy()
mutations = em.mutations.copy()

for mutation in mutations:
    
    if mutation[0] == "C":
        start[mutation[1]] = mutation[2]
        
    if mutation[0] == "I":
        start.insert(mutation[1], mutation[2])
        
    if mutation[0] == "D":
        del start[mutation[1]]
        
print(start == experiment.first_specimen)
# Out:
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# <ipython-input-19-ccc3c8124f10> in <module>
#       9
#      10     if mutation[0] == "C":
# ---> 11         start[mutation[1]] = mutation[2]
#      12
#      13     if mutation[0] == "I":
#
# IndexError: list assignment index out of range

# %%
"""
Recreating the program at all generations

After running this script, lineage[i] contains the program at generation i,
generation 0 being the original ancestor, generation 1 its child and so on
"""

generations = mutations[-1][-1] + 1

start = em.ancestor.copy()
mutations = em.mutations.copy()

temp = start.copy()

lineage = [start]

for i in range(generations):
    
    for mutation in mutations:
        
        if mutation[-1] == i:
            
            if mutation[0] == "C":
                temp[mutation[1]] = mutation[2]
        
            if mutation[0] == "I":
                temp.insert(mutation[1], mutation[2])
        
            if mutation[0] == "D":
                del temp[mutation[1]]
                
    lineage.append(temp.copy())
    
print("Full lineage of the organism: ")
for specimen in lineage:
    print(specimen)
    print("\n")
